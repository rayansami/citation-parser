# %%
"""
    This code block downsamples each csv with 4.5M data into n data
"""
import pandas as pd
import os
import glob
import numpy as np
import multiprocessing
import string
import random
import time

def multiprocessing_func(csv_files):
    #print('Chunked dataset shape in this process: {}'.format(x.shape))
    ''' Use datatuples to write into text file'''
    for csv in csv_files:
        print("Now working on: {}".format(csv))        
        dataset = pd.read_csv(csv)
        # History of downsized-100: Each 100 and total RANDOM Down sample to 250025
        dataset = dataset.sample(n=1564) 
        '''
        newDataset = pd.DataFrame(columns=['doi','articleType','citationStyle','citationStringAnnotated']) 
        citationStyles = dataset['citationStyle'].unique()
        for style in citationStyles:
            listonStyle = dataset.loc[dataset['citationStyle'] == style]
            newDataset = newDataset.append(listonStyle.sample(n=3))
        '''
        
        length = 5 # length of filename
        randomstr = ''.join(random.choices(string.ascii_letters+string.digits,k=length))
        filename = randomstr +'.csv'
        filepath = r"/home/muddi004/muddi/GIANT/downsized-1564-v2/" + filename
        '''
        newDataset.to_csv(filepath, index = False, header = True)
        '''
        dataset.to_csv(filepath, index = False, header = True)
        
        print('Done Writing {}'.format(csv))


# use glob to get all the csv files 
# in the folder
csvDirectory = r"/home/muddi004/muddi/GIANT/Source-CSV" # Original CSV Source
csv_files = glob.glob(os.path.join(csvDirectory, "*.csv"))
#csv_files = csv_files[201:]
print(len(csv_files))

start = time.time()
print("Starting now")
n_proc = 40 # TODO: Change number of available processors
chunks = np.array_split(csv_files, n_proc) # Chunk CSV file paths
print(len(csv_files))
print(len(chunks))

processes=[] #Initialize the parallel processes list
for i in np.arange(0,n_proc):    
    """Execute the target function on the n_proc target processors using the splitted input""" 
    p = multiprocessing.Process(target=multiprocessing_func,args=(chunks[i],))
    processes.append(p)
    p.start()
for process in processes:
    process.join()

end = time.time()
print("Total time required: {}".format(end - start))
# Out:
# 219
# Starting now
# 219
# 40
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (145).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (163).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (111).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (37).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (30).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (146).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (171).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (150).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (116).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (179).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (4).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (14).csvNow working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (164).csvNow working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (203).csvNow working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (11).csvNow working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (112).csvNow working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (16).csv
#
#
#
#
#
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (141).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (78).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (97).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (80).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (8).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (216).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (1).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (12).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (110).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (140).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (33).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (73).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (25).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (96).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (147).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (81).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (198).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (66).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (22).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (186).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (84).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (217).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (187).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (179).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (121).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (30).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (172).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (141).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (5).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (37).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (177).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (16).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (74).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (147).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (28).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (14).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (52).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (146).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (128).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (163).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (175).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (111).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (76).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (66).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (108).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (112).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (129).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (116).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (55).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (33).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (139).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (186).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (130).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (171).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (36).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (150).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (119).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (1).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (88).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (12).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (31).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (11).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (41).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (25).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (26).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (4).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (67).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (73).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (103).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (84).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (209).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (97).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (210).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (198).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (162).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (164).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (58).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (217).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (166).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (8).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (50).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (203).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (204).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (80).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (91).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (81).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (107).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (216).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (47).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (96).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (10).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (187).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (83).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (78).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (184).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (140).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (101).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (22).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (2).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (110).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (212).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (145).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (148).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (5).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (135).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (177).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (199).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (172).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (159).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (28).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (201).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (52).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (155).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (121).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (120).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (128).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (151).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (74).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (194).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (175).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (134).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (139).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (157).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (55).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (46).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (108).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (142).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (76).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (137).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (129).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (219).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (130).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (188).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (36).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (75).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (119).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (127).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (31).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (158).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (88).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (167).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (67).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (206).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (103).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (7).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (41).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (87).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (26).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (99).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (209).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (196).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (58).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (21).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (210).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (15).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (50).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (89).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (166).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (200).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (204).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (34).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (162).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (6).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (107).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (180).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (91).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (207).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (2).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (51).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (47).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (77).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (10).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (143).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (184).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (114).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (83).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (215).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (101).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (185).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (148).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (122).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (212).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (43).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (219).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (124).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (199).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (18).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (151).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (69).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (155).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (48).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (159).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (118).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (201).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (183).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (135).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (169).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (194).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (109).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (46).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (60).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (134).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (176).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (120).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (178).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (157).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (70).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (137).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (104).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (142).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (126).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (188).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (132).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (75).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (100).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (206).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (208).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (127).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (71).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (7).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (54).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (158).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (149).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (167).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (93).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (87).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (23).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (196).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (63).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (99).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (160).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (21).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (27).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (15).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (92).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (200).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (102).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (34).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (17).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (89).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (154).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (6).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (181).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (180).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (123).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (207).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (38).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (51).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (136).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (77).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (24).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (143).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (106).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (114).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (131).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (122).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (117).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (185).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (190).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (215).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (144).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (43).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (218).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (124).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (182).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (18).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (105).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (118).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (197).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (178).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (13).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (176).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (214).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (60).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (170).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (69).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (9).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (183).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (72).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (48).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (161).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (169).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (59).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (109).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (19).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (104).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (173).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (132).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (153).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (208).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (44).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (70).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (64).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (126).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (205).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (100).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (42).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (149).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (20).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (71).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (62).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (93).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (165).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (54).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (39).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (23).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (56).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (160).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (189).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (92).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (86).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (102).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (138).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (27).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (115).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (154).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (82).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (17).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (195).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (123).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (40).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (181).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (45).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (63).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (133).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (136).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (174).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (24).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (95).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (106).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (65).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (117).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (191).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (190).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (113).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (38).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (125).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (131).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (79).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (218).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (57).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (144).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (168).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (182).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (35).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (105).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (68).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (197).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (3).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (170).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (85).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (214).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (152).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (161).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (213).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (9).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (29).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (13).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (202).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (19).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (94).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (72).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (173).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (98).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (59).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (53).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (44).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (32).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (153).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (205).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (64).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (42).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (211).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (62).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (49).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (39).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (20).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (56).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (192).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (189).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (82).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (86).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (195).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (90).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (115).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (156).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (40).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (165).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (45).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (174).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (138).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (65).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (133).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (113).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (95).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (191).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (61).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (168).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (125).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (57).csv
# Done Writing /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (79).csv
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (193).csv

# %%
'''
    Build: Test Dataset maintaining different citation style
'''
import pandas as pd
import os
import glob
import numpy as np
import multiprocessing
import string
import random
import time

csvDirectory = r"/home/muddi004/muddi/GIANT/Source-CSV/"
csv_files = glob.glob(os.path.join(csvDirectory, "*.csv"))
#print(csv_files)
for csv in csv_files:
    print("Now working on: {}".format(csv))
    dataset = pd.read_csv(csv)
    newDataset = pd.DataFrame(columns=['doi','articleType','citationStyle','citationStringAnnotated']) 
    
    citationStyles = dataset['citationStyle'].unique()
    for style in citationStyles:
        listonStyle = dataset.loc[dataset['citationStyle'] == style]
        newDataset = newDataset.append(listonStyle.sample(n=1))

    length = 5 # length of filename
    randomstr = ''.join(random.choices(string.ascii_letters+string.digits,k=length))
    filename = randomstr +'.csv'
    #filename = 'sample_one.csv'
    filepath = r"/home/muddi004/muddi/GIANT/downsized-1564/" + filename
    newDataset.to_csv(filepath, index = False, header = True)
    
    
#n_proc = 40 # TODO: Change number of available processors
#chunks = np.array_split(csv_files, n_proc)

#print(chunks[38].shape)
# Out:
# Now working on: /home/muddi004/muddi/GIANT/Source-CSV/1 Billion Citation Dataset, v1 (145).csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3e09c503dad1> in <module>
#      29     #filename = 'sample_one.csv'
#      30     filepath = r"/home/muddi004/muddi/GIANT/data/downsized-1564/" + filename
# ---> 31     newDataset.to_csv(filepath, index = False, header = True)
#      32
#      33
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3398             doublequote=doublequote,
#    3399             escapechar=escapechar,
# -> 3400             storage_options=storage_options,
#    3401         )
#    3402
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     642                 encoding=ioargs.encoding,
#     643                 errors=errors,
# --> 644                 newline="",
#     645             )
#     646         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/muddi004/muddi/GIANT/data/downsized-1564/6ZERz.csv'
