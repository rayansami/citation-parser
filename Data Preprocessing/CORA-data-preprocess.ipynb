# %%
'''
    CORA dataset builder
    
    Hotfixes:
     1) Pages - Remove "pp." and "pages" around digits
     2) Volume - Remove "Vol."
'''
import pandas as pd
import os
import glob
import numpy as np
import multiprocessing
import string
import random
import time
import itertools
import re

# ----- Tokenizer Starts ----- #

'''
  This method takes element and label and produce the proper BOI label for each token
  elemnt -> Can be XML token, word token or punctuation token
'''
def getTagLabelPairs(element, label=None):
  resultList = []
  punc = r"[\/ ,.:;()\"'?!+@#{\[}\]\\$^&*-]"
  tagLabel = []
  result = re.match("<[^>]+>",element) # Check if element is a string with XML
  initLabel = False #
  if result and label: # Enter if element is XML string
    element = re.sub("<[^>]+>", "", element) # Remove all XML tag from element
    if label == 'PAGE': # HOTFIX
        element = re.sub("[^\d-]+", "", element) ## For pages - remove anything other then digit & hyphen
    s = re.findall(r"\w+|[^\w\s]", element) # Split the element(with XML tag) into words and punctuation 
    for item in s:
      if item in punc:
        resultList.append((item,'B-PUNC'))
      else:
        if initLabel is False:
          initLabel = True
          resultList.append((item,'B-'+label))
        else:
          resultList.append((item,'I-'+label))
  else: # Works when element is anything other then string of XML tag. Can be punctuation or words outside of XML tag in ciation string
    # Either punctuation or other tag to anything outside of [defined] XML tag
    pattern = re.compile(punc)        
    result = pattern.match(element)
    if pattern.match(element): 
      resultList.append((element,'B-PUNC'))    
    else:
      resultList.append((element,'O'))    

  return resultList

# Utility method : Remove ASCII and unicodes
def strip_non_ascii(string):
  ''' Returns the string without non ASCII characters'''
  stripped = (c for c in string if 0 < ord(c) < 127)
  return ''.join(stripped)

'''
  Input:
  ciation string -> XML tagged citation string from GIANT dataset
'''
def tokenizeCitation(citationString):
  """
    Remove URL/DOI from the annotated citation string
    And cleanup texts before URL/DOI tags
    TODO: Currently keeping out of URL/DOI. Will work on this later
  """
  citationString = strip_non_ascii(citationString.replace('–','-').encode("ascii", "ignore").decode()) # Fixing GIANT training data citation string error and removing unicode

  urlExists = False
  doiExists = False
  urlordoi = None
  '''
    tech <remove>
    institute <remove> 
    editor <remove> 
    location
  '''
  if "editor" in citationString:
        citationString = re.sub('<editor>.+<\/editor>', "", citationString)
  if "institute" in citationString:
        citationString = re.sub('<institute>.+<\/institute>', "", citationString)
  if "institution" in citationString:
        citationString = re.sub('<institution>.+<\/institution>', "", citationString)
  if "tech" in citationString:
        citationString = re.sub('<tech>.+<\/tech>', "", citationString)     
  if "location" in citationString:
        citationString = re.sub('<location>.+<\/location>', "", citationString)   
  if "note" in citationString:
        citationString = re.sub('<note>.+<\/note>', "", citationString)           
        
  if "<URL>" in citationString:
    urlExists = True
    """
      re.findall [0] gets the matched string
      re.sub gives the text inside the tag
    """
    urlordoi = re.sub('<[^<]+>', "", re.findall('<URL>.+<\/URL>',citationString)[0]) 
    citationString = re.sub('<URL>.+<\/URL>', "", citationString)
  if "<DOI>" in citationString:
    doiExists = True
    urlordoi = re.sub('<[^<]+>', "", re.findall('<DOI>.+<\/DOI>',citationString)[0]) 
    citationString = re.sub('<DOI>.+<\/DOI>', "", citationString)

  tokens = []
  tags = []
  unprocessedTokens = []


  charPattern = r"[\w\d]"
  noCharPattern = r"[\/ ,.:;()\"'?!+@#{\[}\]\\$^&*-]" 
  endPtr = 0
  word = ""

  """
    Seperating non-word and words(with tags) at first 
    e.g. ['<author><family>Mehrinfar<family>', ',', ' ', '<given>Ramona<given>']
    [Processed them later]
  """
  tag = False
  tagName = ''
  elseCounter = 0
  while endPtr < len(citationString):
    # Keep everything inside the XML tag
    if citationString[endPtr] == '<':
      tag = True  

    if tag:      
      tagName += citationString[endPtr]

      if citationString[endPtr] == '>':
        tag = False
        tagName = tagName[-len(tagName)+1:-1] # Tag name excluding < & >
        tagExpression = r"<"+tagName+">.+<\/"+tagName+">" # <DOI>.+<\/DOI>
        p = re.compile(tagExpression)        
        result = p.search(citationString)
        if result:
          token = result.group()     # group(1) will return the 1st capture (stuff within the brackets).
          unprocessedTokens.append(token)   
          citationString = re.sub(tagExpression,'',citationString)
          
          endPtr = elseCounter
          tagName = ""
          word = ""
    else:
      # If it's not XML tag, look for char & non-char 
      if re.search(charPattern, citationString[endPtr]):
        word += citationString[endPtr]
      elif re.search(noCharPattern, citationString[endPtr]):
        if word is not "":
          unprocessedTokens.append(word)   
        unprocessedTokens.append(citationString[endPtr])
        word = ""
      elseCounter += 1  
    endPtr = endPtr + 1

  #print(unprocessedTokens)

  for item in unprocessedTokens:
    if item == ' ' or item == '':
      unprocessedTokens.remove(item)

  #print(unprocessedTokens)
  '''
    author -> author
    date -> date
    title -> title
    booktitle / journal -> based on citationType. If not found then containerTitle
    volume -> volume
    publisher -> publisher
    pages -> page
    other
  '''
  sentence = []
  for item in unprocessedTokens:    
    if "author" in item:
      sentence.append(getTagLabelPairs(item,"AUTHOR"))
    elif "booktitle" in item or "journal" in item:
      sentence.append(getTagLabelPairs(item,"CT"))      
    elif "title" in item:
      sentence.append(getTagLabelPairs(item,"TITLE"))
    elif "date" in item:
      sentence.append(getTagLabelPairs(item,"DATE"))
    elif "volume" in item:
      # EDIT =>  Vol.
      #item = re.sub('Vol.', "", item) # HOTFIX
      sentence.append(getTagLabelPairs(item,"VOL"))        
    elif "pages" in item:
      # EDIT => pp.
      #item = re.sub('pp.', "", item) # HOTFIX
      sentence.append(getTagLabelPairs(item,"PAGE"))
    elif "publisher" in item:
      sentence.append(getTagLabelPairs(item,"PUBLISHER"))            
    else:
      sentence.append(getTagLabelPairs(item))

  sentence = list(itertools.chain.from_iterable(sentence))  
  #print("Sentence {}".format(sentence))

  # If returning a list-of-token & list-of-tags is needed.
  

  tokens = []
  tags = []
  ''' Remove spaces from the processed tokens '''
  for item in sentence:
    if item[0]==' ' or item[0]=='':
        pass
    else:
        tokens.append(item[0])
        tags.append(item[1])

  #print("sentence {}".format(sentence))
  #print("Tokens {}".format(tokens))
  #print("Tags {}".format(tags))

  return (tokens,tags)
  #return sentence

# ----- Tokenizer Ends ----- #    

# Get processed Gold Dataset
def getDataTuples(dataset):
    """
        Input# dataset: n rows of annotated ciation strings 
        
        Process# Prepare each citation string using tokenizer mothod which returns word-label list
                 from a annotated citation string
        
        Output# List(List(word-lable tuple of one citation string))
    """

    '''Read the dataset'''
    
    ''' Prepare dataframe for tuples'''    
    df2 = pd.DataFrame(columns=['Tokens'])
    df3 = pd.DataFrame(columns=['Tags'])
    for data in dataset:
        tokenizerResponse = tokenizeCitation(data.strip())
        #print("Response: {}".format(tokenizerResponse))
        df2 = df2.append({'Tokens': tokenizerResponse[0]}, ignore_index=True)
        df3 = df3.append({'Tags': tokenizerResponse[1]}, ignore_index=True)        

    
    data = pd.concat([df2,df3],axis=1)

    ''' Prepare list of tuples'''
    datatuple = []
    for index, row in data.iterrows():
        tuples = []
        for idx in range(len(row['Tokens'])):
            # Yeilding out the spaces
            if row['Tokens'][idx] is not ' ':
                tuples.append((row['Tokens'][idx], row['Tags'][idx]))
        datatuple.append(tuples)
    print(datatuple)
    return datatuple

with open ("muddi/citationParser/CORA/tagged_references.txt", "r") as myfile:
    data = myfile.read().splitlines()
    print(type(data))
    for index in range(10):
        data_subset = random.sample(data, 50)
        #print(data_subset[0])

        datatuple = getDataTuples(data_subset)
        #print(datatuple[0])
        filename = 'cora_test_sample_'+str(index+1)+'.txt'
        filepath = 'muddi/citationParser/CORA/'+filename
        with open(filepath, 'a+') as fileValid:  
            for sentence in datatuple:
                for tuples in sentence:                
                    fileValid.write("{}\t{}\n".format(tuples[0],tuples[1]))    
                fileValid.write("\n")
# Out:
# <class 'list'>
# [[('Leroy', 'B-AUTHOR'), (',', 'B-PUNC'), ('X', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Typage', 'B-TITLE'), ('polymorphe', 'I-TITLE'), ('d', 'I-TITLE'), ("'", 'B-PUNC'), ('un', 'I-TITLE'), ('langage', 'I-TITLE'), ('algorithmique', 'I-TITLE'), ('.', 'B-PUNC'), ('7', 'B-DATE'), (',', 'B-PUNC'), ('1992', 'I-DATE'), ('.', 'B-PUNC')], [('Arthur', 'B-AUTHOR'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Keller', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('Julie', 'I-AUTHOR'), ('Basu', 'I-AUTHOR'), ('.', 'B-PUNC'), ('A', 'B-TITLE'), ('predicate', 'I-TITLE'), ('-', 'B-PUNC'), ('based', 'I-TITLE'), ('caching', 'I-TITLE'), ('scheme', 'I-TITLE'), ('for', 'I-TITLE'), ('client', 'I-TITLE'), ('-', 'B-PUNC'), ('server', 'I-TITLE'), ('database', 'I-TITLE'), ('architectures', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('PDIS', 'I-CT'), ('-', 'B-PUNC'), ('94', 'I-CT'), (',', 'B-PUNC'), ('1994', 'B-DATE'), ('.', 'B-PUNC')], [('Bylander', 'B-AUTHOR'), (',', 'B-PUNC'), ('T', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1992', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Complexity', 'B-TITLE'), ('results', 'I-TITLE'), ('for', 'I-TITLE'), ('serial', 'I-TITLE'), ('decomposability', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('National', 'I-CT'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Artificial', 'I-CT'), ('Intelligence', 'I-CT'), (',', 'B-PUNC'), ('729', 'B-PAGE'), ('-', 'B-PUNC'), ('734', 'I-PAGE'), ('AAAI', 'B-PUBLISHER'), ('Press', 'I-PUBLISHER'), ('.', 'B-PUNC')], [('D', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Lomet', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('Mark', 'I-AUTHOR'), ('R', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Tuttle', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Redo', 'B-TITLE'), ('Recovery', 'I-TITLE'), ('after', 'I-TITLE'), ('System', 'I-TITLE'), ('Crashes', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proc', 'I-CT'), ('.', 'B-PUNC'), ('of', 'I-CT'), ('the', 'I-CT'), ('21st', 'I-CT'), ('International', 'I-CT'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Very', 'I-CT'), ('Large', 'I-CT'), ('Data', 'I-CT'), ('Bases', 'I-CT'), (',', 'B-PUNC'), ('Sept', 'B-DATE'), ('.', 'B-PUNC'), ('1995', 'I-DATE'), ('.', 'B-PUNC')], [('J', 'B-AUTHOR'), ('.', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Koenderink', 'I-AUTHOR'), ('.', 'B-PUNC'), ('The', 'B-TITLE'), ('structure', 'I-TITLE'), ('of', 'I-TITLE'), ('images', 'I-TITLE'), ('.', 'B-PUNC'), ('Biological', 'B-CT'), ('Cybernetics', 'I-CT'), (',', 'B-PUNC'), ('50', 'B-VOL'), ('363', 'B-PAGE'), ('-', 'B-PUNC'), ('396', 'I-PAGE'), ('1984', 'B-DATE'), ('.', 'B-PUNC')], [('Litman', 'B-AUTHOR'), (',', 'B-PUNC'), ('D', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Hirschberg', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1990', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Disambiguating', 'B-TITLE'), ('cue', 'I-TITLE'), ('phrases', 'I-TITLE'), ('in', 'I-TITLE'), ('text', 'I-TITLE'), ('and', 'I-TITLE'), ('speech', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('Thirteenth', 'I-CT'), ('International', 'I-CT'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Computational', 'I-CT'), ('Linguistics', 'I-CT'), ('(', 'B-PUNC'), ('COLING', 'I-CT'), (')', 'B-PUNC'), ('.', 'B-PUNC')], [('E', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Berlekamp', 'I-AUTHOR'), ('.', 'B-PUNC'), ('"', 'B-PUNC'), ('Factoring', 'B-TITLE'), ('polynomials', 'I-TITLE'), ('over', 'I-TITLE'), ('large', 'I-TITLE'), ('finite', 'I-TITLE'), ('fields', 'I-TITLE'), (',', 'B-PUNC'), ('"', 'B-PUNC'), ('Mathematics', 'B-CT'), ('of', 'I-CT'), ('Computation', 'I-CT'), (',', 'B-PUNC'), ('Vol', 'B-VOL'), ('.', 'B-PUNC'), ('24', 'I-VOL'), (',', 'B-PUNC'), ('No', 'I-VOL'), ('.', 'B-PUNC'), ('111', 'I-VOL'), (',', 'B-PUNC'), ('713', 'B-PAGE'), ('-', 'B-PUNC'), ('735', 'I-PAGE'), ('(', 'B-PUNC'), ('1970', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC')], [('F', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Jahanian', 'I-AUTHO ...
# [[('K', 'B-AUTHOR'), ('.', 'B-PUNC'), ('H', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Wolf', 'I-AUTHOR'), (',', 'B-PUNC'), ('K', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Froitzheim', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('P', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Schulthess', 'I-AUTHOR'), (',', 'B-PUNC'), ('(', 'B-PUNC'), ('1995', 'B-DATE'), (')', 'B-PUNC'), ('Multimedia', 'B-TITLE'), ('Application', 'I-TITLE'), ('Sharing', 'I-TITLE'), ('in', 'I-TITLE'), ('a', 'I-TITLE'), ('Heterogeneous', 'I-TITLE'), ('Environment', 'I-TITLE'), (',', 'B-PUNC'), ('ACM', 'B-CT'), ('Multimedia', 'I-CT'), ('95', 'I-CT'), (',', 'B-PUNC'), ('57', 'B-PAGE'), ('-', 'B-PUNC'), ('64', 'I-PAGE')], [('W', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Li', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Linearly', 'B-TITLE'), ('convergent', 'I-TITLE'), ('descent', 'I-TITLE'), ('methods', 'I-TITLE'), ('for', 'I-TITLE'), ('unconstrained', 'I-TITLE'), ('minimization', 'I-TITLE'), ('of', 'I-TITLE'), ('convex', 'I-TITLE'), ('quadratic', 'I-TITLE'), ('splines', 'I-TITLE'), ('.', 'B-PUNC'), ('1993', 'B-DATE'), ('.', 'B-PUNC'), ('Journal', 'B-CT'), ('of', 'I-CT'), ('Optimization', 'I-CT'), ('Theory', 'I-CT'), ('and', 'I-CT'), ('Applications', 'I-CT'), (',', 'B-PUNC')], [('Litman', 'B-AUTHOR'), (',', 'B-PUNC'), ('D', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Hirschberg', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1990', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Disambiguating', 'B-TITLE'), ('cue', 'I-TITLE'), ('phrases', 'I-TITLE'), ('in', 'I-TITLE'), ('text', 'I-TITLE'), ('and', 'I-TITLE'), ('speech', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('Thirteenth', 'I-CT'), ('International', 'I-CT'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Computational', 'I-CT'), ('Linguistics', 'I-CT'), ('(', 'B-PUNC'), ('COLING', 'I-CT'), (')', 'B-PUNC'), ('.', 'B-PUNC')], [('Narayana', 'B-AUTHOR'), (',', 'B-PUNC'), ('K', 'I-AUTHOR'), ('.', 'B-PUNC'), ('T', 'I-AUTHOR'), ('.', 'B-PUNC'), ('and', 'I-AUTHOR'), ('Aaby', 'I-AUTHOR'), (',', 'B-PUNC'), ('A', 'I-AUTHOR'), ('.', 'B-PUNC'), ('A', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('"', 'B-PUNC'), ('Specification', 'B-TITLE'), ('of', 'I-TITLE'), ('Real', 'I-TITLE'), ('-', 'B-PUNC'), ('Time', 'I-TITLE'), ('Systems', 'I-TITLE'), ('in', 'I-TITLE'), ('Real', 'I-TITLE'), ('-', 'B-PUNC'), ('Time', 'I-TITLE'), ('Temporal', 'I-TITLE'), ('Interval', 'I-TITLE'), ('Logic', 'I-TITLE'), ('"', 'B-PUNC'), (',', 'B-PUNC'), ('Proceedings', 'B-CT'), ('of', 'I-CT'), ('Real', 'I-CT'), ('-', 'B-PUNC'), ('Time', 'I-CT'), ('Systems', 'I-CT'), ('Symposium', 'I-CT'), (',', 'B-PUNC'), ('December', 'B-DATE'), ('1988', 'I-DATE'), ('.', 'B-PUNC')], [('U', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Kremer', 'I-AUTHOR'), (',', 'B-PUNC'), ('H', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Zima', 'I-AUTHOR'), (',', 'B-PUNC'), ('H', 'I-AUTHOR'), ('.', 'B-PUNC'), ('-', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Bast', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Gerndt', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Advanced', 'B-TITLE'), ('tools', 'I-TITLE'), ('and', 'I-TITLE'), ('techniques', 'I-TITLE'), ('for', 'I-TITLE'), ('automatic', 'I-TITLE'), ('parallelization', 'I-TITLE'), ('.', 'B-PUNC'), ('Parallel', 'B-CT'), ('Computing', 'I-CT'), (',', 'B-PUNC'), ('7', 'B-VOL'), ('387', 'B-PAGE'), ('-', 'B-PUNC'), ('393', 'I-PAGE'), ('1988', 'B-DATE'), ('.', 'B-PUNC')], [('Allen', 'B-AUTHOR'), (',', 'B-PUNC'), ('James', 'I-AUTHOR'), ('F', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1979', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('A', 'B-TITLE'), ('Plan', 'I-TITLE'), ('-', 'B-PUNC'), ('Based', 'I-TITLE'), ('Approach', 'I-TITLE'), ('to', 'I-TITLE'), ('Speech', 'I-TITLE'), ('Act', 'I-TITLE'), ('Recognition', 'I-TITLE'), ('.', 'B-PUNC')], [('L', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Lovasz', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('N', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Young', 'I-AUTHOR'),  ...
# [[('R', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Lipsett', 'I-AUTHOR'), (',', 'B-PUNC'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Schaefer', 'I-AUTHOR'), (',', 'B-PUNC'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Ussery', 'I-AUTHOR'), (',', 'B-PUNC'), ('VHDL', 'B-TITLE'), (':', 'B-PUNC'), ('Hardware', 'I-TITLE'), ('Description', 'I-TITLE'), ('and', 'I-TITLE'), ('Design', 'I-TITLE'), (',', 'B-PUNC'), ('Kluwer', 'B-PUBLISHER'), ('Academic', 'I-PUBLISHER'), ('Publishers', 'I-PUBLISHER'), (',', 'B-PUNC'), ('1989', 'B-DATE'), ('.', 'B-PUNC')], [('Emihovich', 'B-AUTHOR'), (',', 'B-PUNC'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Miller', 'I-AUTHOR'), (',', 'B-PUNC'), ('G', 'I-AUTHOR'), ('.', 'B-PUNC'), ('E', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1988', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Talking', 'B-TITLE'), ('to', 'I-TITLE'), ('the', 'I-TITLE'), ('turtle', 'I-TITLE'), (':', 'B-PUNC'), ('A', 'I-TITLE'), ('discourse', 'I-TITLE'), ('analysis', 'I-TITLE'), ('of', 'I-TITLE'), ('Logo', 'I-TITLE'), ('instruction', 'I-TITLE'), ('.', 'B-PUNC'), ('Discourse', 'B-CT'), ('Processes', 'I-CT'), (',', 'B-PUNC'), ('11', 'B-VOL'), (',', 'B-PUNC'), ('183', 'B-PAGE'), ('-', 'B-PUNC'), ('201', 'I-PAGE')], [('Ancona', 'B-AUTHOR'), (',', 'B-PUNC'), ('D', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('Zucca', 'I-AUTHOR'), (',', 'B-PUNC'), ('E', 'I-AUTHOR'), ('.', 'B-PUNC'), ('An', 'B-TITLE'), ('algebraic', 'I-TITLE'), ('approach', 'I-TITLE'), ('to', 'I-TITLE'), ('mixins', 'I-TITLE'), ('and', 'I-TITLE'), ('modularity', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proc', 'I-CT'), ('.', 'B-PUNC'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Algebraic', 'I-CT'), ('and', 'I-CT'), ('Logic', 'I-CT'), ('Programming', 'I-CT'), ('1996', 'B-DATE'), (')', 'B-PUNC'), (',', 'B-PUNC')], [('Y', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Sagiv', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Yannakakis', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Equivalence', 'B-TITLE'), ('among', 'I-TITLE'), ('relational', 'I-TITLE'), ('expressions', 'I-TITLE'), ('with', 'I-TITLE'), ('the', 'I-TITLE'), ('union', 'I-TITLE'), ('and', 'I-TITLE'), ('difference', 'I-TITLE'), ('operators', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('J', 'I-CT'), ('.', 'B-PUNC'), ('ACM', 'I-CT'), ('27', 'B-VOL'), ('(', 'B-PUNC'), ('4', 'I-VOL'), (')', 'B-PUNC'), ('633', 'B-PAGE'), ('-', 'B-PUNC'), ('655', 'I-PAGE'), ('1981', 'B-DATE'), ('.', 'B-PUNC')], [('Hauptman', 'B-AUTHOR'), (',', 'B-PUNC'), ('H', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Karle', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1953', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Solution', 'B-TITLE'), ('of', 'I-TITLE'), ('the', 'I-TITLE'), ('Phase', 'I-TITLE'), ('Problem', 'I-TITLE'), (',', 'B-PUNC'), ('1', 'I-TITLE'), ('.', 'B-PUNC'), ('The', 'I-TITLE'), ('Centrosymmetric', 'I-TITLE'), ('Crystal', 'I-TITLE'), (',', 'B-PUNC'), ('ACA', 'B-CT'), ('Monograph', 'I-CT'), ('No', 'B-VOL'), ('.', 'B-PUNC'), ('3', 'I-VOL'), ('.', 'B-PUNC'), ('Polycrystal', 'B-PUBLISHER'), ('Book', 'I-PUBLISHER'), ('Service', 'I-PUBLISHER'), ('.', 'B-PUNC')], [('G', 'B-AUTHOR'), ('.', 'B-PUNC'), ('E', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Blelloch', 'I-AUTHOR'), (',', 'B-PUNC'), ('S', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Chatterjee', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Hardwick', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Sipelstein', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Zagha', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Implementation', 'B-TITLE'), ('of', 'I-TITLE'), ('a', 'I-TITLE'), ('portable', 'I-TITLE'), ('nested', 'I-TITLE'), ('data', 'I-TITLE'), ('-', 'B-PUNC'), ('parallel', 'I-TITLE'), ('language', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('4th', 'I-CT'), ('Symposium', 'I-CT'), ('on', 'I-CT'), ('Principl ...
# [[('Peter', 'B-AUTHOR'), ('Puschner', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('Anton', 'I-AUTHOR'), ('Schedl', 'I-AUTHOR'), ('.', 'B-PUNC'), ('A', 'B-TITLE'), ('tool', 'I-TITLE'), ('for', 'I-TITLE'), ('the', 'I-TITLE'), ('computation', 'I-TITLE'), ('of', 'I-TITLE'), ('worst', 'I-TITLE'), ('case', 'I-TITLE'), ('task', 'I-TITLE'), ('execution', 'I-TITLE'), ('times', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proc', 'I-CT'), ('.', 'B-PUNC'), ('of', 'I-CT'), ('the', 'I-CT'), ('5th', 'I-CT'), ('EUROMICRO', 'I-CT'), ('Workshop', 'I-CT'), ('on', 'I-CT'), ('Real', 'I-CT'), ('-', 'B-PUNC'), ('Time', 'I-CT'), ('Systems', 'I-CT'), (',', 'B-PUNC'), ('1993', 'B-DATE'), ('.', 'B-PUNC')], [('R', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Fagin', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Halpern', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Vardi', 'I-AUTHOR'), ('.', 'B-PUNC'), ('A', 'B-TITLE'), ('model', 'I-TITLE'), ('-', 'B-PUNC'), ('theoretic', 'I-TITLE'), ('analysis', 'I-TITLE'), ('of', 'I-TITLE'), ('knowledge', 'I-TITLE'), ('.', 'B-PUNC'), ('Journal', 'B-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('ACM', 'I-CT'), (',', 'B-PUNC'), ('38', 'B-VOL'), ('(', 'B-PUNC'), ('2', 'I-VOL'), (')', 'B-PUNC'), (',', 'B-PUNC'), ('382', 'B-PAGE'), ('-', 'B-PUNC'), ('428', 'I-PAGE'), ('1991', 'B-DATE'), ('.', 'B-PUNC')], [('Albert', 'B-AUTHOR'), ('R', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Meyer', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('Mitchell', 'I-AUTHOR'), ('Wand', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Continuation', 'B-TITLE'), ('semantics', 'I-TITLE'), ('in', 'I-TITLE'), ('typed', 'I-TITLE'), ('lambda', 'I-TITLE'), ('calculi', 'I-TITLE'), ('(', 'B-PUNC'), ('summary', 'I-TITLE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Logics', 'B-CT'), ('of', 'I-CT'), ('Programs', 'I-CT'), (',', 'B-PUNC'), ('volume', 'I-CT'), ('193', 'I-CT'), (',', 'B-PUNC'), ('of', 'I-CT'), ('Lecture', 'I-CT'), ('Notes', 'I-CT'), ('in', 'I-CT'), ('Computer', 'I-CT'), ('Science', 'I-CT'), (',', 'B-PUNC'), ('219', 'B-PAGE'), ('-', 'B-PUNC'), ('224', 'I-PAGE'), ('Springer', 'B-PUBLISHER'), ('-', 'B-PUNC'), ('Verlag', 'I-PUBLISHER'), (',', 'B-PUNC'), ('1985', 'B-DATE'), ('.', 'B-PUNC')], [('T', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Carpenter', 'I-AUTHOR'), (',', 'B-PUNC'), ('K', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Driscoll', 'I-AUTHOR'), (',', 'B-PUNC'), ('K', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Hoyme', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Carciofini', 'I-AUTHOR'), ('.', 'B-PUNC'), ('ARINC659', 'B-TITLE'), ('acheduling', 'I-TITLE'), (':', 'B-PUNC'), ('Problem', 'I-TITLE'), ('definition', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('Real', 'I-CT'), ('Time', 'I-CT'), ('Systems', 'I-CT'), ('Symposium', 'I-CT'), (',', 'B-PUNC'), ('165', 'B-PAGE'), ('-', 'B-PUNC'), ('169', 'I-PAGE'), ('December', 'B-DATE'), ('1994', 'I-DATE'), ('.', 'B-PUNC')], [('F', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Facchinei', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Kanzow', 'I-AUTHOR'), ('.', 'B-PUNC'), ('On', 'B-TITLE'), ('unconstrained', 'I-TITLE'), ('and', 'I-TITLE'), ('constrained', 'I-TITLE'), ('stationary', 'I-TITLE'), ('points', 'I-TITLE'), ('of', 'I-TITLE'), ('the', 'I-TITLE'), ('implicit', 'I-TITLE'), ('Lagrangian', 'I-TITLE'), ('.', 'B-PUNC'), ('Journal', 'B-CT'), ('of', 'I-CT'), ('Optimization', 'I-CT'), ('Theory', 'I-CT'), ('and', 'I-CT'), ('Applications', 'I-CT'), (',', 'B-PUNC'), ('92', 'B-VOL'), ('99', 'B-PAGE'), ('-', 'B-PUNC'), ('115', 'I-PAGE'), ('1997', 'B-DATE'), ('.', 'B-PUNC')], [('I', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Koren', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('A', 'I-AUTHOR'), ('.', 'B-PUNC'), ('D', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Singh', 'I-AUTHOR'), (',', 'B-PUNC'), ('"', 'B-PUNC'), ('Fault', 'B-TITLE'), ('Tolerance', 'I-TITLE'), ('in', 'I-TITLE'), ('VLSI', 'I-TITLE'), ('Circuits', 'I-TITLE'), (',', 'B-PUNC'), ('"', 'B-PUNC'), ('Computer ...
# [[('Mooney', 'B-AUTHOR'), (',', 'B-PUNC'), ('R', 'I-AUTHOR'), ('.', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1990', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Learning', 'B-TITLE'), ('plan', 'I-TITLE'), ('schemata', 'I-TITLE'), ('from', 'I-TITLE'), ('observation', 'I-TITLE'), (':', 'B-PUNC'), ('Explanation', 'I-TITLE'), ('-', 'B-PUNC'), ('based', 'I-TITLE'), ('learning', 'I-TITLE'), ('for', 'I-TITLE'), ('plan', 'I-TITLE'), ('recognition', 'I-TITLE'), ('.', 'B-PUNC'), ('Cognitive', 'B-CT'), ('Science', 'I-CT'), (',', 'B-PUNC'), ('14', 'B-VOL'), (',', 'B-PUNC'), ('483', 'B-PAGE'), ('-', 'B-PUNC'), ('509', 'I-PAGE')], [('De', 'B-AUTHOR'), ('Raedt', 'I-AUTHOR'), (',', 'B-PUNC'), ('L', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Bruynooghe', 'I-AUTHOR'), (',', 'B-PUNC'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1990', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Indirect', 'B-TITLE'), ('relevance', 'I-TITLE'), ('and', 'I-TITLE'), ('bias', 'I-TITLE'), ('in', 'I-TITLE'), ('inductive', 'I-TITLE'), ('concept', 'I-TITLE'), ('learning', 'I-TITLE'), ('.', 'B-PUNC'), ('Knowledge', 'B-CT'), ('Acquisition', 'I-CT'), (',', 'B-PUNC'), ('2', 'B-VOL'), (',', 'B-PUNC'), ('365', 'B-PAGE'), ('-', 'B-PUNC'), ('390', 'I-PAGE'), ('(', 'B-PUNC'), ('1995', 'O'), (')', 'B-PUNC'), ('.', 'B-PUNC')], [('Shoham', 'B-AUTHOR'), (',', 'B-PUNC'), ('Y', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1988', 'B-TITLE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Reasoning', 'I-TITLE'), ('about', 'I-TITLE'), ('Change', 'I-TITLE'), ('.', 'B-PUNC'), ('Cambridge', 'I-TITLE'), (',', 'B-PUNC'), ('MIT', 'I-TITLE'), ('Press', 'I-TITLE'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1989', 'I-TITLE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Semantic', 'B-CT'), ('parallels', 'I-CT'), ('in', 'I-CT'), ('natural', 'I-CT'), ('language', 'I-CT'), ('and', 'I-CT'), ('computation', 'I-CT'), ('.', 'B-PUNC')], [('Pryor', 'B-AUTHOR'), (',', 'B-PUNC'), ('L', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Collins', 'I-AUTHOR'), (',', 'B-PUNC'), ('G', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1993', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Cassandra', 'B-TITLE'), (':', 'B-PUNC'), ('Planning', 'I-TITLE'), ('with', 'I-TITLE'), ('contingencies', 'I-TITLE'), ('.', 'B-PUNC')], [('A', 'B-AUTHOR'), ('.', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Bernstein', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Analysis', 'B-TITLE'), ('of', 'I-TITLE'), ('programs', 'I-TITLE'), ('for', 'I-TITLE'), ('parallel', 'I-TITLE'), ('processing', 'I-TITLE'), ('.', 'B-PUNC'), ('IEEE', 'B-CT'), ('Transactions', 'I-CT'), ('on', 'I-CT'), ('Electronic', 'I-CT'), ('Computers', 'I-CT'), (',', 'B-PUNC'), ('757', 'B-PAGE'), ('-', 'B-PUNC'), ('763', 'I-PAGE'), ('October', 'B-DATE'), ('1966', 'I-DATE'), ('.', 'B-PUNC')], [('R', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Lipsett', 'I-AUTHOR'), (',', 'B-PUNC'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Schaefer', 'I-AUTHOR'), (',', 'B-PUNC'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Ussery', 'I-AUTHOR'), (',', 'B-PUNC'), ('VHDL', 'B-TITLE'), (':', 'B-PUNC'), ('Hardware', 'I-TITLE'), ('Description', 'I-TITLE'), ('and', 'I-TITLE'), ('Design', 'I-TITLE'), (',', 'B-PUNC'), ('Kluwer', 'B-PUBLISHER'), ('Academic', 'I-PUBLISHER'), ('Publishers', 'I-PUBLISHER'), (',', 'B-PUNC'), ('1989', 'B-DATE'), ('.', 'B-PUNC')], [('Geddes', 'B-AUTHOR'), (',', 'B-PUNC'), ('K', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('Czapor', 'I-AUTHOR'), (',', 'B-PUNC'), ('S', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('Labahn', 'I-AUTHOR'), (',', 'B-PUNC'), ('G', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Algorithms', 'B-TITLE'), ('for', 'I-TITLE'), ('Computer', 'I-TITLE'), ('Algebra', 'I-TITLE'), ('.', 'B-PUNC'), ('Kluwer', 'B-PUBLISHER'), ('Academic', 'I-PUBLISHER'), ('Publishers', 'I-PUBLISHER'), (',', 'B-PUNC'), ('1992', 'B-DATE'), ('.', 'B-PUNC')], [('Wellman', 'B-AUTHOR'), ('Kephart', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR' ...
# [[('Albert', 'B-AUTHOR'), ('R', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Meyer', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('Mitchell', 'I-AUTHOR'), ('Wand', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Continuation', 'B-TITLE'), ('semantics', 'I-TITLE'), ('in', 'I-TITLE'), ('typed', 'I-TITLE'), ('lambda', 'I-TITLE'), ('calculi', 'I-TITLE'), ('(', 'B-PUNC'), ('summary', 'I-TITLE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Logics', 'B-CT'), ('of', 'I-CT'), ('Programs', 'I-CT'), (',', 'B-PUNC'), ('volume', 'I-CT'), ('193', 'I-CT'), (',', 'B-PUNC'), ('of', 'I-CT'), ('Lecture', 'I-CT'), ('Notes', 'I-CT'), ('in', 'I-CT'), ('Computer', 'I-CT'), ('Science', 'I-CT'), (',', 'B-PUNC'), ('219', 'B-PAGE'), ('-', 'B-PUNC'), ('224', 'I-PAGE'), ('Springer', 'B-PUBLISHER'), ('-', 'B-PUNC'), ('Verlag', 'I-PUBLISHER'), (',', 'B-PUNC'), ('1985', 'B-DATE'), ('.', 'B-PUNC')], [('Hill', 'B-AUTHOR'), (',', 'B-PUNC'), ('P', 'I-AUTHOR'), ('.', 'B-PUNC'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('and', 'I-AUTHOR'), ('Lloyd', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('W', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('The', 'B-TITLE'), ('Godel', 'I-TITLE'), ('Programming', 'I-TITLE'), ('Language', 'I-TITLE'), (',', 'B-PUNC'), ('MIT', 'B-PUBLISHER'), ('Press', 'I-PUBLISHER'), (',', 'B-PUNC'), ('1994', 'B-DATE'), ('.', 'B-PUNC')], [('N', 'B-AUTHOR'), ('.', 'B-PUNC'), ('A', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Lorentzos', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('Y', 'I-AUTHOR'), ('.', 'B-PUNC'), ('G', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Mitsopoulos', 'I-AUTHOR'), ('.', 'B-PUNC'), ('SQL', 'B-TITLE'), ('Extension', 'I-TITLE'), ('for', 'I-TITLE'), ('Interval', 'I-TITLE'), ('Data', 'I-TITLE'), ('.', 'B-PUNC'), ('IEEE', 'B-CT'), ('TKDE', 'I-CT'), (',', 'B-PUNC'), ('9', 'B-VOL'), ('(', 'B-PUNC'), ('3', 'I-VOL'), (')', 'B-PUNC'), ('480', 'B-PAGE'), ('-', 'B-PUNC'), ('499', 'I-PAGE'), ('May', 'B-DATE'), ('1997', 'I-DATE'), ('.', 'B-PUNC')], [('F', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Rabiti', 'I-AUTHOR'), (',', 'B-PUNC'), ('E', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Brtino', 'I-AUTHOR'), (',', 'B-PUNC'), ('W', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Kim', 'I-AUTHOR'), (',', 'B-PUNC'), ('D', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Woelk', 'I-AUTHOR'), (',', 'B-PUNC'), ('A', 'B-TITLE'), ('Model', 'I-TITLE'), ('of', 'I-TITLE'), ('Authorization', 'I-TITLE'), ('for', 'I-TITLE'), ('Next', 'I-TITLE'), ('-', 'B-PUNC'), ('Generation', 'I-TITLE'), ('Database', 'I-TITLE'), ('Systems', 'I-TITLE'), (',', 'B-PUNC')], [('W', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Landi', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('B', 'I-AUTHOR'), ('.', 'B-PUNC'), ('G', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Ryder', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Aliasing', 'B-TITLE'), ('with', 'I-TITLE'), ('and', 'I-TITLE'), ('without', 'I-TITLE'), ('pointers', 'I-TITLE'), (':', 'B-PUNC'), ('A', 'I-TITLE'), ('problem', 'I-TITLE'), ('taxonomy', 'I-TITLE'), ('.', 'B-PUNC'), ('September', 'B-DATE'), ('1990', 'I-DATE'), ('.', 'B-PUNC')], [('U', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Dayal', 'I-AUTHOR'), (',', 'B-PUNC'), ('H', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Garcia', 'I-AUTHOR'), ('-', 'B-PUNC'), ('Molina', 'I-AUTHOR'), (',', 'B-PUNC'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Hsu', 'I-AUTHOR'), (',', 'B-PUNC'), ('B', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Kao', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('-', 'B-PUNC'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Shan', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Third', 'B-TITLE'), ('generation', 'I-TITLE'), ('TP', 'I-TITLE'), ('monitors', 'I-TITLE'), (':', 'B-PUNC'), ('A', 'I-TITLE'), ('database', 'I-TITLE'), ('challenge', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('ACM', 'I-CT'), ('SIGMOD', 'I-CT'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Management', 'I-CT'), ('of', 'I-CT'), ('Data', 'I-CT'), (',', 'B-PUNC'), ('393', 'B-PAGE'), ('-', 'B-PUNC'), ('397', 'I-PAGE'), ('May', 'B-DATE'), ('1993', 'I-DATE'), ('.', 'B-PUNC')], [('T', 'B-AUTHOR'), ('.', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Sabin', 'I-AUTHOR'), (',', ' ...
# [[('Robert', 'B-AUTHOR'), ('A', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Ballance', 'I-AUTHOR'), (',', 'B-PUNC'), ('Arthur', 'I-AUTHOR'), ('B', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Maccabe', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('Karl', 'I-AUTHOR'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Ottenstein', 'I-AUTHOR'), ('.', 'B-PUNC'), ('The', 'B-TITLE'), ('program', 'I-TITLE'), ('dependence', 'I-TITLE'), ('web', 'I-TITLE'), (':', 'B-PUNC'), ('A', 'I-TITLE'), ('representation', 'I-TITLE'), ('supporting', 'I-TITLE'), ('control', 'I-TITLE'), ('-', 'B-PUNC'), (',', 'B-PUNC'), ('data', 'I-TITLE'), ('-', 'B-PUNC'), (',', 'B-PUNC'), ('and', 'I-TITLE'), ('demand', 'I-TITLE'), ('-', 'B-PUNC'), ('driven', 'I-TITLE'), ('interpretation', 'I-TITLE'), ('of', 'I-TITLE'), ('imperative', 'I-TITLE'), ('languages', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proc', 'I-CT'), ('.', 'B-PUNC'), ('of', 'I-CT'), ('Sigplan', 'I-CT'), ("'", 'B-PUNC'), ('90', 'I-CT'), ('Conf', 'I-CT'), ('.', 'B-PUNC'), ('on', 'I-CT'), ('Programming', 'I-CT'), ('Language', 'I-CT'), ('Design', 'I-CT'), ('and', 'I-CT'), ('Implementation', 'I-CT'), (',', 'B-PUNC'), ('257', 'B-PAGE'), ('-', 'B-PUNC'), ('271', 'I-PAGE'), ('1990', 'B-DATE'), ('.', 'B-PUNC')], [('Hel', 'B-AUTHOR'), ('-', 'B-PUNC'), ('Or', 'I-AUTHOR'), (',', 'B-PUNC'), ('Y', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Werman', 'I-AUTHOR'), (',', 'B-PUNC'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1992', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Absolute', 'B-TITLE'), ('orientation', 'I-TITLE'), ('from', 'I-TITLE'), ('uncertain', 'I-TITLE'), ('data', 'I-TITLE'), (':', 'B-PUNC'), ('A', 'I-TITLE'), ('unified', 'I-TITLE'), ('approach', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proc', 'I-CT'), ('.', 'B-PUNC'), ('Intern', 'I-CT'), ('.', 'B-PUNC'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Computer', 'I-CT'), ('Vision', 'I-CT'), ('and', 'I-CT'), ('Pattern', 'I-CT'), ('Recognition', 'I-CT'), (',', 'B-PUNC'), ('77', 'B-PAGE'), ('-', 'B-PUNC'), ('82', 'I-PAGE')], [('MacWhinney', 'B-AUTHOR'), (',', 'B-PUNC'), ('B', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1993', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Connections', 'B-TITLE'), ('and', 'I-TITLE'), ('symbols', 'I-TITLE'), (':', 'B-PUNC'), ('closing', 'I-TITLE'), ('the', 'I-TITLE'), ('gap', 'I-TITLE'), ('.', 'B-PUNC'), ('Cognition', 'B-CT'), (',', 'B-PUNC'), ('49', 'B-VOL'), ('(', 'B-PUNC'), ('3', 'I-VOL'), (')', 'B-PUNC'), (',', 'B-PUNC'), ('291', 'B-PAGE'), ('-', 'B-PUNC'), ('296', 'I-PAGE')], [('A', 'B-AUTHOR'), ('.', 'B-PUNC'), ('V', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Aho', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('E', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Hopcroft', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('D', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Ullman', 'I-AUTHOR'), (',', 'B-PUNC'), ('The', 'B-TITLE'), ('Design', 'I-TITLE'), ('and', 'I-TITLE'), ('Analysis', 'I-TITLE'), ('of', 'I-TITLE'), ('Computer', 'I-TITLE'), ('Algorithms', 'I-TITLE'), (',', 'B-PUNC'), ('Addison', 'B-PUBLISHER'), ('-', 'B-PUNC'), ('Wesley', 'I-PUBLISHER'), (',', 'B-PUNC'), ('1974', 'B-DATE'), ('.', 'B-PUNC')], [('D', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Ourston', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('R', 'I-AUTHOR'), ('.', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Mooney', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Changing', 'B-TITLE'), ('the', 'I-TITLE'), ('Rules', 'I-TITLE'), (':', 'B-PUNC'), ('A', 'I-TITLE'), ('Comprehensive', 'I-TITLE'), ('Approach', 'I-TITLE'), ('to', 'I-TITLE'), ('Theory', 'I-TITLE'), ('Refinement', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('Eighth', 'I-CT'), ('International', 'I-CT'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Machine', 'I-CT'), ('Learning', 'I-CT'), (',', 'B-PUNC'), ('485', 'B-PAGE'), ('-', 'B-PUNC'), ('489', 'I-PAGE'), ('1991', 'B-DATE'), ('.', 'B-PUNC')], [('Marr', 'B-AUTHOR'), (',', 'B-PUNC ...
# [[('J', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Allen', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Koomen', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Planning', 'B-TITLE'), ('using', 'I-TITLE'), ('a', 'I-TITLE'), ('temporal', 'I-TITLE'), ('world', 'I-TITLE'), ('model', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proc', 'I-CT'), ('.', 'B-PUNC'), ('IJCAI', 'I-CT'), (',', 'B-PUNC'), ('741', 'B-PAGE'), ('-', 'B-PUNC'), ('747', 'I-PAGE'), ('1983', 'B-DATE'), ('.', 'B-PUNC')], [('Litman', 'B-AUTHOR'), (',', 'B-PUNC'), ('D', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Hirschberg', 'I-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1990', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Disambiguating', 'B-TITLE'), ('cue', 'I-TITLE'), ('phrases', 'I-TITLE'), ('in', 'I-TITLE'), ('text', 'I-TITLE'), ('and', 'I-TITLE'), ('speech', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('Thirteenth', 'I-CT'), ('International', 'I-CT'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Computational', 'I-CT'), ('Linguistics', 'I-CT'), ('(', 'B-PUNC'), ('COLING', 'I-CT'), (')', 'B-PUNC'), ('.', 'B-PUNC')], [('P', 'B-AUTHOR'), ('.', 'B-PUNC'), ('T', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Zellweger', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Interactions', 'B-TITLE'), ('between', 'I-TITLE'), ('high', 'I-TITLE'), ('-', 'B-PUNC'), ('level', 'I-TITLE'), ('debugging', 'I-TITLE'), ('and', 'I-TITLE'), ('optimised', 'I-TITLE'), ('code', 'I-TITLE'), ('.', 'B-PUNC'), ('1984', 'B-DATE'), ('.', 'B-PUNC')], [('Ling', 'B-AUTHOR'), ('Tony', 'I-AUTHOR'), ('Chen', 'I-AUTHOR'), (',', 'B-PUNC'), ('R', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Drach', 'I-AUTHOR'), (',', 'B-PUNC'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Keating', 'I-AUTHOR'), (',', 'B-PUNC'), ('S', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Louis', 'I-AUTHOR'), (',', 'B-PUNC'), ('Doron', 'I-AUTHOR'), ('Rotem', 'I-AUTHOR'), (',', 'B-PUNC'), ('Arie', 'I-AUTHOR'), ('Shoshani', 'I-AUTHOR'), (',', 'B-PUNC'), ('Efficient', 'B-TITLE'), ('organization', 'I-TITLE'), ('and', 'I-TITLE'), ('access', 'I-TITLE'), ('of', 'I-TITLE'), ('multidimensional', 'I-TITLE'), ('datasets', 'I-TITLE'), ('on', 'I-TITLE'), ('tertiary', 'I-TITLE'), ('storage', 'I-TITLE'), ('systems', 'I-TITLE'), (',', 'B-PUNC'), ('Information', 'B-CT'), ('Systems', 'I-CT'), ('20', 'B-VOL'), ('(', 'B-PUNC'), ('2', 'I-VOL'), (')', 'B-PUNC'), (',', 'B-PUNC'), ('155', 'B-PAGE'), ('-', 'B-PUNC'), ('183', 'I-PAGE'), ('(', 'B-PUNC'), ('1995', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC')], [('Harry', 'B-AUTHOR'), ('Heffes', 'I-AUTHOR'), ('and', 'I-AUTHOR'), ('David', 'I-AUTHOR'), ('Lucantoni', 'I-AUTHOR'), ('.', 'B-PUNC'), ('A', 'B-TITLE'), ('markov', 'I-TITLE'), ('modulated', 'I-TITLE'), ('characterization', 'I-TITLE'), ('of', 'I-TITLE'), ('voice', 'I-TITLE'), ('and', 'I-TITLE'), ('data', 'I-TITLE'), ('traffic', 'I-TITLE'), ('and', 'I-TITLE'), ('related', 'I-TITLE'), ('statistical', 'I-TITLE'), ('multiplexer', 'I-TITLE'), ('performance', 'I-TITLE'), ('.', 'B-PUNC'), ('IEEE', 'B-CT'), ('J', 'I-CT'), ('.', 'B-PUNC'), ('Select', 'I-CT'), ('.', 'B-PUNC'), ('Areas', 'I-CT'), ('Commun', 'I-CT'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('SAC', 'B-VOL'), ('-', 'B-PUNC'), ('4', 'I-VOL'), (',', 'B-PUNC'), ('856', 'B-PAGE'), ('-', 'B-PUNC'), ('867', 'I-PAGE'), ('September', 'B-DATE'), ('1986', 'I-DATE'), ('.', 'B-PUNC')], [('M', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Reiman', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('B', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Simon', 'I-AUTHOR'), ('.', 'B-PUNC'), ('An', 'B-TITLE'), ('Interpolation', 'I-TITLE'), ('Approximation', 'I-TITLE'), ('for', 'I-TITLE'), ('Queueing', 'I-TITLE'), ('Systems', 'I-TITLE'), ('with', 'I-TITLE'), ('Poisson', 'I-TITLE'), ('Input', 'I-TITLE'), ('.', 'B-PUNC'), ('Operations', 'B-CT'), ('Research', 'I-CT'), ('36', 'B-VOL'), (',', 'B-PUNC'), ('3', 'I-VOL'), ('(', 'B-PUNC'), ('1988', 'B-DATE'), (')', 'B-PUNC'), (',', 'B-PUNC'), ('454', 'B-PAG ...
# [[('Ting', 'B-AUTHOR'), (',', 'B-PUNC'), ('Kai', 'I-AUTHOR'), ('Ming', 'I-AUTHOR'), (',', 'B-PUNC'), ('(', 'B-PUNC'), ('1996', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Discretisation', 'B-TITLE'), ('in', 'I-TITLE'), ('Lazy', 'I-TITLE'), ('Learning', 'I-TITLE'), ('.', 'B-PUNC'), ('the', 'B-CT'), ('special', 'I-CT'), ('issue', 'I-CT'), ('on', 'I-CT'), ('Lazy', 'I-CT'), ('Learning', 'I-CT'), ('in', 'I-CT'), ('Artificial', 'I-CT'), ('Intelligence', 'I-CT'), ('Review', 'I-CT'), ('.', 'B-PUNC')], [('Laird', 'B-AUTHOR'), (',', 'B-PUNC'), ('J', 'I-AUTHOR'), ('.', 'B-PUNC'), ('E', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('Jones', 'I-AUTHOR'), (',', 'B-PUNC'), ('R', 'I-AUTHOR'), ('.', 'B-PUNC'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Nielsen', 'I-AUTHOR'), (',', 'B-PUNC'), ('P', 'I-AUTHOR'), ('.', 'B-PUNC'), ('E', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1994', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Coordinated', 'B-TITLE'), ('behavior', 'I-TITLE'), ('of', 'I-TITLE'), ('computer', 'I-TITLE'), ('generated', 'I-TITLE'), ('forces', 'I-TITLE'), ('in', 'I-TITLE'), ('tacair', 'I-TITLE'), ('-', 'B-PUNC'), ('soar', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('Fourth', 'I-CT'), ('Conference', 'I-CT'), ('on', 'I-CT'), ('Computer', 'I-CT'), ('Generated', 'I-CT'), ('Forces', 'I-CT'), ('and', 'I-CT'), ('Behavioral', 'I-CT'), ('Representation', 'I-CT'), ('.', 'B-PUNC')], [('Y', 'B-AUTHOR'), ('.', 'B-PUNC'), ('Breitbart', 'I-AUTHOR'), (',', 'B-PUNC'), ('A', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Silberschatz', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('G', 'I-AUTHOR'), ('.', 'B-PUNC'), ('R', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Thompson', 'I-AUTHOR'), ('.', 'B-PUNC'), ('An', 'B-TITLE'), ('approach', 'I-TITLE'), ('to', 'I-TITLE'), ('recovery', 'I-TITLE'), ('management', 'I-TITLE'), ('in', 'I-TITLE'), ('a', 'I-TITLE'), ('multidatabase', 'I-TITLE'), ('system', 'I-TITLE'), ('.', 'B-PUNC'), ('The', 'B-CT'), ('VLDB', 'I-CT'), ('Journal', 'I-CT'), (',', 'B-PUNC'), ('1', 'B-VOL'), ('(', 'B-PUNC'), ('11', 'I-VOL'), (')', 'B-PUNC'), (',', 'B-PUNC'), ('July', 'B-DATE'), ('1992', 'I-DATE'), ('.', 'B-PUNC')], [('Ware', 'B-AUTHOR'), (',', 'B-PUNC'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), ('&', 'B-PUNC'), ('Slipp', 'I-AUTHOR'), (',', 'B-PUNC'), ('L', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1991', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Using', 'B-TITLE'), ('velocity', 'I-TITLE'), ('control', 'I-TITLE'), ('to', 'I-TITLE'), ('navigate', 'I-TITLE'), ('3D', 'I-TITLE'), ('graphical', 'I-TITLE'), ('environments', 'I-TITLE'), (':', 'B-PUNC'), ('a', 'I-TITLE'), ('comparison', 'I-TITLE'), ('of', 'I-TITLE'), ('three', 'I-TITLE'), ('interfaces', 'I-TITLE'), ('.', 'B-PUNC'), ('Proceedings', 'B-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('Human', 'I-CT'), ('Factors', 'I-CT'), ('Society', 'I-CT'), ('35th', 'I-CT'), ('annual', 'I-CT'), ('meeting', 'I-CT'), ('.', 'B-PUNC')], [('Cau', 'B-AUTHOR'), (',', 'B-PUNC'), ('A', 'I-AUTHOR'), ('.', 'B-PUNC'), ('and', 'I-AUTHOR'), ('Zedan', 'I-AUTHOR'), (',', 'B-PUNC'), ('H', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('"', 'B-PUNC'), ('Refining', 'B-TITLE'), ('Interval', 'I-TITLE'), ('Temporal', 'I-TITLE'), ('Logic', 'I-TITLE'), ('specifications', 'I-TITLE'), ('"', 'B-PUNC'), (',', 'B-PUNC'), ('November', 'B-DATE'), ('1996', 'I-DATE'), ('.', 'B-PUNC')], [('De', 'B-AUTHOR'), ('Raedt', 'I-AUTHOR'), (',', 'B-PUNC'), ('L', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('Lavrac', 'I-AUTHOR'), (',', 'B-PUNC'), ('N', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Dzeroski', 'I-AUTHOR'), (',', 'B-PUNC'), ('S', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1993', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Multiple', 'B-TITLE'), ('predicate', 'I-TITLE'), ('learning', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('Third', 'I-CT'), ('Intern ...
# [[('Thomas', 'B-AUTHOR'), ('von', 'I-AUTHOR'), ('Eicken', 'I-AUTHOR'), (',', 'B-PUNC'), ('David', 'I-AUTHOR'), ('E', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Culler', 'I-AUTHOR'), (',', 'B-PUNC'), ('Seth', 'I-AUTHOR'), ('Copen', 'I-AUTHOR'), ('Goldstein', 'I-AUTHOR'), (',', 'B-PUNC'), ('and', 'I-AUTHOR'), ('Karl', 'I-AUTHOR'), ('Erik', 'I-AUTHOR'), ('Schauser', 'I-AUTHOR'), ('.', 'B-PUNC'), ('Active', 'B-TITLE'), ('messages', 'I-TITLE'), (':', 'B-PUNC'), ('A', 'I-TITLE'), ('mechanism', 'I-TITLE'), ('for', 'I-TITLE'), ('integrated', 'I-TITLE'), ('communication', 'I-TITLE'), ('and', 'I-TITLE'), ('computation', 'I-TITLE'), ('.', 'B-PUNC'), ('In', 'B-CT'), ('Proceedings', 'I-CT'), ('of', 'I-CT'), ('the', 'I-CT'), ('19th', 'I-CT'), ('Annual', 'I-CT'), ('International', 'I-CT'), ('Symposium', 'I-CT'), ('on', 'I-CT'), ('Computer', 'I-CT'), ('Architecture', 'I-CT'), (',', 'B-PUNC'), ('256', 'B-PAGE'), ('-', 'B-PUNC'), ('266', 'I-PAGE'), ('May', 'B-DATE'), ('1992', 'I-DATE'), ('.', 'B-PUNC')], [('Forsyth', 'B-AUTHOR'), (',', 'B-PUNC'), ('C', 'I-AUTHOR'), ('.', 'B-PUNC'), ('H', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('Implementation', 'B-TITLE'), ('of', 'I-TITLE'), ('the', 'I-TITLE'), ('Worst', 'I-TITLE'), ('-', 'B-PUNC'), ('Case', 'I-TITLE'), ('Execution', 'I-TITLE'), ('Time', 'I-TITLE'), ('Analyser', 'I-TITLE'), ('June', 'B-DATE'), ('1992', 'I-DATE'), (',', 'B-PUNC'), ('Task', 'B-CT'), ('8', 'I-CT'), ('Volume', 'I-CT'), ('E', 'I-CT'), ('Deliverable', 'I-CT'), ('on', 'I-CT'), ('ESTEC', 'I-CT'), ('contract', 'I-CT'), ('9198', 'I-CT'), ('/', 'B-PUNC'), ('90', 'I-CT'), ('/', 'B-PUNC'), ('NL', 'I-CT'), ('/', 'B-PUNC'), ('SF', 'I-CT')], [('Gupta', 'B-AUTHOR'), (',', 'B-PUNC'), ('R', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('Smolka', 'I-AUTHOR'), (',', 'B-PUNC'), ('S', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('&', 'B-PUNC'), ('Bhaskar', 'I-AUTHOR'), (',', 'B-PUNC'), ('S', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1994', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('On', 'B-TITLE'), ('randomization', 'I-TITLE'), ('in', 'I-TITLE'), ('sequential', 'I-TITLE'), ('and', 'I-TITLE'), ('distributed', 'I-TITLE'), ('algorithms', 'I-TITLE'), ('.', 'B-PUNC'), ('ACM', 'B-CT'), ('Computing', 'I-CT'), ('Surveys', 'I-CT'), (',', 'B-PUNC'), ('26', 'B-VOL'), ('(', 'B-PUNC'), ('1', 'I-VOL'), (')', 'B-PUNC'), (',', 'B-PUNC'), ('7', 'B-PAGE'), ('-', 'B-PUNC'), ('86', 'I-PAGE')], [('Topics', 'B-TITLE'), ('in', 'I-TITLE'), ('Case', 'I-TITLE'), ('-', 'B-PUNC'), ('Based', 'I-TITLE'), ('Reasoning', 'I-TITLE'), ('.', 'B-PUNC'), ('Springer', 'B-PUBLISHER'), ('-', 'B-PUNC'), ('Verlag', 'I-PUBLISHER'), (',', 'B-PUNC'), ('167', 'B-PAGE'), ('-', 'B-PUNC'), ('181', 'I-PAGE')], [('Forbus', 'B-AUTHOR'), (',', 'B-PUNC'), ('K', 'I-AUTHOR'), ('.', 'B-PUNC'), ('D', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1989', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Introducing', 'B-TITLE'), ('Actions', 'I-TITLE'), ('in', 'I-TITLE'), ('Qualitative', 'I-TITLE'), ('Simulation', 'I-TITLE'), ('.', 'B-PUNC'), ('Proceedings', 'B-CT'), ('of', 'I-CT'), ('IJCAI', 'I-CT'), ('-', 'B-PUNC'), ('89', 'I-CT'), (',', 'B-PUNC'), ('1273', 'B-PAGE'), ('-', 'B-PUNC'), ('1278', 'I-PAGE')], [('Jennings', 'B-AUTHOR'), (',', 'B-PUNC'), ('N', 'I-AUTHOR'), ('.', 'B-PUNC'), ('(', 'B-PUNC'), ('1994', 'B-DATE'), (')', 'B-PUNC'), ('.', 'B-PUNC'), ('Commitments', 'B-TITLE'), ('and', 'I-TITLE'), ('conventions', 'I-TITLE'), (':', 'B-PUNC'), ('the', 'I-TITLE'), ('foundation', 'I-TITLE'), ('of', 'I-TITLE'), ('coordination', 'I-TITLE'), ('in', 'I-TITLE'), ('multi', 'I-TITLE'), ('-', 'B-PUNC'), ('agent', 'I-TITLE'), ('systems', 'I-TITLE'), ('.', 'B-PUNC'), ('The', 'B-CT'), ('Knowledge', 'I-CT'), ('Engineering', 'I-CT'), ('Review', 'I-CT'), (',', 'B-PUNC'), ('8', 'B-VOL'), ('.', 'B-PUNC')], [('Rao', 'B-AUTHOR'), (',', 'B-PUNC'), ('A', 'I-AUTHOR'), ('.', 'B-PUNC'), ('S', 'I-AUTHOR'), ('.', 'B-PUNC'), (',', 'B-PUNC'), ('Georgeff', 'I-AUTHOR'), (',', 'B-PUNC'), ('M', 'I-AUTHOR'), ('.', 'B-PUNC'), ('P ...

# %%
with open ("muddi/citationParser/CORA/tagged_references.txt", "r") as myfile:
    data = myfile.read().splitlines()

print(data[0])
# Out:
# <author> A. Cau, R. Kuiper, and W.-P. de Roever. </author> <title> Formalising Dijkstra's development strategy within Stark's formalism. </title> <editor> In C. B. Jones, R. C. Shaw, and T. Denvir, editors, </editor> <booktitle> Proc. 5th. BCS-FACS Refinement Workshop, </booktitle> <date> 1992. </date>
