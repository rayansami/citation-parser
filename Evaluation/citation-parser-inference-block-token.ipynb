# %%
'''
    This block loads the saved models. For each model, there are -
    1. word_field_obj.pth
    2. tag_field_obj.pth
    3. char_field_obj.pth
    4. transformermodel.pth [Trained weights]
'''
import os
import time
import gensim
from collections import Counter

import torch
from torch import nn
from torch.optim import Adam
from torch.optim import AdamW
from spacy.lang.id import Indonesian
import gensim.models.keyedvectors as word2vec
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import re
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report

import math
import time
import gensim
import matplotlib.pyplot as plt

from torchtext.legacy.data import Field, NestedField, BucketIterator
from torchtext.legacy.datasets import SequenceTaggingDataset
from torchtext.legacy.vocab import Vocab
from torchcrf import CRF
from collections import Counter
from spacy.lang.id import Indonesian
import logging
import gc
import torch.utils
import torch.utils.checkpoint

import torch.nn.utils.prune as prune
import torch.nn.functional as F


from transformerModel import Transformer, PositionalEncoding

"""
    Load saved model
"""
modelPath = r"/home/muddi004/muddi/citationParser/savedmodel/220K/"
available_gpu = torch.cuda.is_available()
if available_gpu:
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
    logging.info(f"GPU is available: {torch.cuda.get_device_name(0)}")
    use_device = torch.device("cuda")
else:
    use_device = torch.device("cpu")

'''
    Load saved Torchtext field objects
'''
word_field = torch.load(modelPath + "word_field_obj.pth")
tag_field = torch.load(modelPath + "tag_field_obj.pth")
char_field = torch.load(modelPath +  "char_field_obj.pth")

# Make sure to call input = input.to(device) on any input tensors that you feed to the model
# use model.eval() before inference
print(len(tag_field.vocab))

unk_idx = word_field.vocab.stoi[word_field.unk_token]
print(unk_idx)

word_pad_idx = word_field.vocab.stoi[word_field.pad_token]
char_pad_idx = char_field.vocab.stoi[char_field.pad_token]
tag_pad_idx = tag_field.vocab.stoi[tag_field.pad_token]

model = Transformer(
    input_dim=len(word_field.vocab),
    embedding_dim=300,
    char_emb_dim=25, #37,  # NEWLY MODIFIED: TRANSFORMER
    char_input_dim=len(char_field.vocab),
    char_cnn_filter_num=4,  # NEWLY MODIFIED: TRANSFORMER
    char_cnn_kernel_size=3,
    char_lstm_hidden=50,
    attn_heads=16,  # NEWLY MODIFIED: TRANSFORMER
    fc_hidden=200,  # NEWLY MODIFIED: TRANSFORMER
    trf_layers=1,
    output_dim=len(tag_field.vocab),
    emb_dropout=0.5,
    cnn_dropout=0.25,
    lstm_dropout = 0.2,
    trf_dropout=0.1,  # NEWLY MODIFIED: TRANSFORMER
    fc_dropout=0.25,
    word_pad_idx=word_pad_idx,
    char_pad_idx=char_pad_idx,
    tag_pad_idx=tag_pad_idx,
    device=use_device
)

# Print model's state_dict
print("Model's state_dict:")
for param_tensor in model.state_dict():
    print(param_tensor, "\t", model.state_dict()[param_tensor].size())
    
#model = nn.DataParallel(model)
model.load_state_dict(torch.load(modelPath +  "transformermodel.pth")) 
model.to(use_device)

print(model)
# Make sure to call input = input.to(device) on any input tensors that you feed to the model
# use model.eval() before inference

'''
    Inference code-block Starts  
'''
def infer(model, tokens, device, true_tags=None, infer_unknown_sentence=True):
    model.eval()
    # tokenize sentence
    #nlp = Indonesian()
    #tokens = [token.text for token in nlp(sentence)]
    tokens = tokens
    max_word_len = max([len(token) for token in tokens])
    # transform to indices based on corpus vocab
    numericalized_tokens = [word_field.vocab.stoi[token.lower()] for token in tokens]
    numericalized_chars = []
    char_pad_id = char_pad_idx
    for token in tokens:
        numericalized_chars.append(
            [char_field.vocab.stoi[char] for char in token]
            + [char_pad_id for _ in range(max_word_len - len(token))]
        )
    # find unknown words
    unk_idx = word_field.vocab.stoi[word_field.unk_token]
    unks = [t for t, n in zip(tokens, numericalized_tokens) if n == unk_idx]
    # begin prediction
    token_tensor = torch.as_tensor(numericalized_tokens)
    token_tensor = token_tensor.unsqueeze(-1).to(device)  # NEWLY MODIFIED: GPU
    char_tensor = torch.as_tensor(numericalized_chars)
    char_tensor = char_tensor.unsqueeze(0).to(device)  # NEWLY MODIFIED: GPU
    predictions, _ = model(token_tensor, char_tensor)
    # convert results to tags
    predicted_tags = [tag_field.vocab.itos[t] for t in predictions[0]]
    # print inferred tags
    max_len_token = max([len(token) for token in tokens] + [len('word')])
    max_len_tag = max([len(tag) for tag in predicted_tags] + [len('pred')])

    if infer_unknown_sentence:
        print(
            f"{'word'.ljust(max_len_token)}\t{'unk'.ljust(max_len_token)}\t{'pred tag'.ljust(max_len_tag)}"
            + ("\ttrue tag" if true_tags else "")
        )
        logging.info(
            f"{'word'.ljust(max_len_token)}\t{'unk'.ljust(max_len_token)}\t{'pred tag'.ljust(max_len_tag)}"
            + ("\ttrue tag" if true_tags else "")
        )
        for i, token in enumerate(tokens):
            is_unk = "✓" if token in unks else ""
            print(
                f"{token.ljust(max_len_token)}\t{is_unk.ljust(max_len_token)}\t{predicted_tags[i].ljust(max_len_tag)}"
                + (f"\t{true_tags[i]}" if true_tags else "")
            )
            logging.info(
                f"{token.ljust(max_len_token)}\t{is_unk.ljust(max_len_token)}\t{predicted_tags[i].ljust(max_len_tag)}"
                + (f"\t{true_tags[i]}" if true_tags else "")
            )
    print(' ')
    return predicted_tags    
'''
    Inference code-block ends  
'''
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# GPU is available: Tesla V100-SXM2-16GB
# 21
# 0
# Model's state_dict:
# embedding.weight 	 torch.Size([3000000, 300])
# char_emb.weight 	 torch.Size([97, 25])
# char_lstm.weight_ih_l0 	 torch.Size([200, 25])
# char_lstm.weight_hh_l0 	 torch.Size([200, 50])
# char_lstm.bias_ih_l0 	 torch.Size([200])
# char_lstm.bias_hh_l0 	 torch.Size([200])
# char_lstm.weight_ih_l0_reverse 	 torch.Size([200, 25])
# char_lstm.weight_hh_l0_reverse 	 torch.Size([200, 50])
# char_lstm.bias_ih_l0_reverse 	 torch.Size([200])
# char_lstm.bias_hh_l0_reverse 	 torch.Size([200])
# position_encoder.pe 	 torch.Size([5000, 1, 400])
# encoder.layers.0.self_attn.in_proj_weight 	 torch.Size([1200, 400])
# encoder.layers.0.self_attn.in_proj_bias 	 torch.Size([1200])
# encoder.layers.0.self_attn.out_proj.weight 	 torch.Size([400, 400])
# encoder.layers.0.self_attn.out_proj.bias 	 torch.Size([400])
# encoder.layers.0.linear1.weight 	 torch.Size([2048, 400])
# encoder.layers.0.linear1.bias 	 torch.Size([2048])
# encoder.layers.0.linear2.weight 	 torch.Size([400, 2048])
# encoder.layers.0.linear2.bias 	 torch.Size([400])
# encoder.layers.0.norm1.weight 	 torch.Size([400])
# encoder.layers.0.norm1.bias 	 torch.Size([400])
# encoder.layers.0.norm2.weight 	 torch.Size([400])
# encoder.layers.0.norm2.bias 	 torch.Size([400])
# fc1.0.weight 	 torch.Size([200, 400])
# fc1.0.bias 	 torch.Size([200])
# fc1_norm.weight 	 torch.Size([200])
# fc1_norm.bias 	 torch.Size([200])
# fc2.weight 	 torch.Size([21, 200])
# fc2.bias 	 torch.Size([21])
# crf.start_transitions 	 torch.Size([21])
# crf.end_transitions 	 torch.Size([21])
# crf.transitions 	 torch.Size([21, 21])
# Transformer(
#   (embedding): Embedding(3000000, 300, padding_idx=1)
#   (emb_dropout): Dropout(p=0.5, inplace=False)
#   (char_emb): Embedding(97, 25, padding_idx=1)
#   (char_lstm): LSTM(25, 50, batch_first=True, bidirectional=True)
#   (lstm_dropout): Dropout(p=0.2, inplace=False)
#   (position_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=400, out_features=400, bias=True)
#         )
#         (linear1): Linear(in_features=400, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=400, bias=True)
#         (norm1): LayerNorm((400,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((400,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=400, out_features=200, bias=True)
#     (1): GELU()
#   )
#   (fc1_norm): LayerNorm((200,), eps=1e-05, elementwise_affine=True)
#   (fc2_dropout): Dropout(p=0.25, inplace=False)
#   (fc2): Linear(in_features=200, out_features=21, bias=True)
#   (crf): CRF(num_tags=21)
# )
# '\n    Inference code-block ends  \n'

# %%
'''
    This block reads the preprocessed text files [Test data] for sentences/tokens which we will infer
    with the trained model
'''
import os
import re
import pandas as pd

# f1_score = []
# def glueTokens(tokens, predicted_tags):
#     # For GIANT test-data: etities will be 11 tags:
#     # name, title, container-title, issue-date, issue-month, page, volume, issue, publisher, issn, source
#     predtag_length = len(predicted_tags)

#     # Get the tuples out of predicted tags and tokens
#     authors_tuple = []
#     title_tuple =[]
#     containertitle_tuple =[]
#     publish_date_tuple = []
#     #publish_month_tuple = []
#     page_tuple = []
#     volume_tuple = []
#     issue_tuple = []
#     publisher_tuple = []
#     issn_tuple = []
#     source_tuple = []
    
#     #beginTitle_idx = 0
#     #endTitle_idx = -1
#     for idx in range(len(predicted_tags)):
#         if "AUTHOR" in predicted_tags[idx]:
#             authors_tuple.append((tokens[idx],predicted_tags[idx]))            
#         elif "CT" in predicted_tags[idx]:
#             containertitle_tuple.append((tokens[idx],predicted_tags[idx]))        
#         elif "TITLE" in predicted_tags[idx]:
#             title_tuple.append((tokens[idx],predicted_tags[idx]))        
#             '''
#             if "B" in predicted_tags[idx]:
#                 beginTitle_idx = idx
#             if "I" in predicted_tags[idx]:
#                 if idx > endTitle_idx:
#                     endTitle_idx = idx
#             '''
#         elif "VOL" in predicted_tags[idx]:
#             volume_tuple.append((tokens[idx],predicted_tags[idx]))
#         elif "ISSUE" in predicted_tags[idx]:
#             issue_tuple.append((tokens[idx],predicted_tags[idx]))
#         elif "PAGE" in predicted_tags[idx]:
#             page_tuple.append((tokens[idx],predicted_tags[idx]))            
#         elif "DATE" in predicted_tags[idx]:
#             publish_date_tuple.append((tokens[idx],predicted_tags[idx]))        
#         elif "PUBLISHER" in predicted_tags[idx]:
#             publisher_tuple.append((tokens[idx],predicted_tags[idx]))            
#         elif "ISSN" in predicted_tags[idx]:
#             issn_tuple.append((tokens[idx],predicted_tags[idx]))
#         elif "SOURCE" in predicted_tags[idx]:
#             source_tuple.append((tokens[idx],predicted_tags[idx]))
                       
#     title = " ".join([title[0] for title in title_tuple])
#     containertitle = " ".join([containertitle[0] for containertitle in containertitle_tuple])
#     publisher = " ".join([publisher[0] for publisher in publisher_tuple])
#     source = " ".join([source[0] for source in source_tuple])
#     issn = " ".join([issn[0] for issn in issn_tuple])
#     issue = " ".join([issue[0] for issue in issue_tuple])
#     volume = " ".join([volume[0] for volume in volume_tuple])
#     page = " ".join([page[0] for page in page_tuple])
#     #publication_month = " ".join([publication_month[0] for publication_month in publish_month_tuple])
#     publication_year = " ".join([publication_year[0] for publication_year in publish_date_tuple])
#     authors = " ".join([author[0] for author in authors_tuple])
    
# #     ''' Managing author names. Considering everyname has a firstname'''
# #     # Store the index of firstnames from author-tuple
# #     firstname_idxs = []
# #     idx = 0
# #     for tpl in authors_tuple:
# #         if "FN" in tpl[1]:
# #             firstname_idxs.append(idx)
        
# #         idx = idx + 1
    
# #     #print(authors_tuple)
# #     #print(range(len(authors_tuple))[0:2])
# #     totalNames = len(firstname_idxs)
# #     for idx in range(totalNames):
# #         name = []
# #         print(firstname_idxs[idx])
# #         if idx+1 < totalNames:
# #             for idx_x in range(len(authors_tuple))[firstname_idxs[idx]:firstname_idxs[idx+1]]:
# #                 name.append(authors_tuple[idx_x][0])
# #         else:
# #             for idx_x in range(len(authors_tuple))[firstname_idxs[idx]:]:
# #                 name.append(authors_tuple[idx_x][0])
        
# #         authors.append(" ".join(name))
          
# #     authors = ",".join(authors)
    
    
#     print("Glued")
#     print("authors: {}".format(authors))
#     print("title: {}".format(title))
#     print("containertitle: {}".format(containertitle))
#     print("issue: {}".format(issue))
#     print("publisher: {}".format(publisher))
#     print("source: {}".format(source))
#     print("issn: {}".format(issn))
#     print("volume: {}".format(volume))
#     print("page: {}".format(page))
#     #print("publication_month: {}".format(publication_month))
#     print("publication_year: {}".format(publication_year))   
    
#     return authors, title, containertitle, issue, publisher, source, issn, volume, page, publication_year
    
            
def predictedtags(tokens,tags=None): # Tokens of one sentence
    # If you want to see [word-predicted tag-true tag] in a list manner of your reference string,
    # set 'infer_unknown_sentence' tag to True
    
    # If you just want the classfication report and do not want to check the predicction labels,
    # then set it false.
    tags = infer(model, tokens=tokens, device=use_device, true_tags=tags, infer_unknown_sentence = True)
    return tags # Predicted tags

def infersentence(sentence,tokens=[],true_tags=[]):    
    for wt_tuple in sentence:
        token = wt_tuple[0]
        tag = wt_tuple[1]
        tokens.append(token)
        true_tags.append(tag)
    
    # Get prediction for tokens of ONE sentence
    predicted_tags = predictedtags(tokens,true_tags) 
    
    return tokens, true_tags, predicted_tags

'''
    Parameter: sentences => List of sentences
    
    Each sentence is list of tuples => [Token-TrueTag] pairs
'''
def inferdata(sentences):
    predicted_tags_all = []
    for sentence in sentences:
        tokens = []
        true_tags = []
        
        for wt_tuple in sentence:
            token = wt_tuple[0]
            tag = wt_tuple[1]
            tokens.append(token)
            true_tags.append(tag)

        predicted_tags = predictedtags(tokens,true_tags)
        predicted_tags_all.append(predicted_tags)
        
    return predicted_tags_all


# ---- Entity Level F1 calculation | Starts ---- #

author = []
ct = []
date =  []
issue = []
page = []
pub = []
punc = []
title = []
vol = []

'''
    Parameter: report 
    Type: string 
    
    It seperates each line and get the f1 scores of each entity. Then accumulate the respective list.
'''
def report_to_df(report):
    report = [x.split(' ') for x in report.split('\n')]
    header = ['Class Name']+[x for x in report[0] if x!='']
    values = []
    for row in report[1:-5]:
        row = [value for value in row if value!='']
        if len(row)>0:            
            if(row[0] == 'AUTHOR'):
                author.append(float(row[3]))
            elif (row[0] == 'CT'):
                ct.append(float(row[3]))
            elif (row[0] == 'DATE'):
                date.append(float(row[3]))
            elif (row[0] == 'ISSUE'):
                issue.append(float(row[3]))
            elif (row[0] == 'PAGE'):
                page.append(float(row[3]))
            elif (row[0] == 'PUBLISHER'):
                pub.append(float(row[3]))
            elif (row[0] == 'PUNC'):
                punc.append(float(row[3]))  
            elif (row[0] == 'TITLE'):
                title.append(float(row[3]))
            elif (row[0] == 'VOL'):
                vol.append(float(row[3]))
    return 1

# ---- Entity Level F1 calculation | Ends ---- #


# Testing source: CORA
sum_f1 = 0.0
os.chdir(r"/home/muddi004/muddi/citationParser/CORA/holdouts/") # This goes to holdout directory where preprocessed test files (CORA) are situated  

# Iterate over the Cora sample files to evaluate
for index in range(10):    
    file_name = 'cora_test_sample_' + str(index+1) + '.txt'
    
    #if file_name != 'cora_test_sample_2.txt':
    #    continue
        
    print('Current CORA Sample: {}'.format(file_name))
    testing_file = open(file_name, encoding="utf8")

    wt_tuple_list = []
    words = []
    tags = []
    
    # Each sentence is a list of word-label pairs
    sentences = [] 

    current_run_f1 = 0.0
    for line in testing_file:
        word_tag = line.split('\t')
        word = word_tag[0].rstrip()

        if len(word_tag) <= 1:
            # On every sentence break (empty line), reset wt_tuple_list
            sentences.append(wt_tuple_list) 
            wt_tuple_list = []
            continue
        else:
            tag = word_tag[1].rstrip()

        words.append(word)
        tags.append(tag)

        wt_tuple = (word,tag)
        if wt_tuple != ('','\n'):
            if wt_tuple != ('',''):
                wt_tuple_list.append(wt_tuple)


    print("Total sentence: {}".format(len(sentences)))
    predicted_lables = inferdata(sentences)

    #Token level performance
    true_labels = [[wt_tuple[1] for wt_tuple in s] for s in sentences]

    
    current_run_f1 = f1_score(true_labels, predicted_lables).item()
    print('Current F1: {}'.format(current_run_f1))
    # Sum up F1 on each iteration to get Avg later
    sum_f1 = sum_f1 + current_run_f1 
    
    print("Precision-score: {:.1%}".format(precision_score(true_labels, predicted_lables)))
    print("Recal-score: {:.1%}".format(recall_score(true_labels, predicted_lables)))    
    print("F1-score: {:.1%}".format(f1_score(true_labels, predicted_lables)))
    print("Classification-report")
    print(classification_report(true_labels, predicted_lables))
    
    # Sum up each entity level F1 score to get Avg later after the Loop
    report = classification_report(true_labels, predicted_lables)
    report_to_df(report)
    

print("Average F1-score: {:.1%}".format(sum_f1/10))
print("Author f1:", sum(author)/len(author))
print("CT f1:", sum(ct)/len(ct))
print("date f1:", sum(date)/len(date))
# print("ISUUE f1:", sum(issue)/len(issue))
print("PAGE f1:", sum(page)/len(page))
print("PUB f1:", sum(pub)/len(pub))
print("punc f1:", sum(punc)/len(punc))
print("title f1:", sum(title)/len(title))
print("vol f1:", sum(vol)/len(vol))
# Out:
# Current CORA Sample: cora_test_sample_2.txt
# Total sentence: 50
# word         	unk          	pred tag	true tag
# K            	             	B-AUTHOR	B-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# H            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Wolf         	             	I-AUTHOR	I-AUTHOR
# ,            	✓            	B-PUNC  	B-PUNC
# K            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Froitzheim   	✓            	I-AUTHOR	I-AUTHOR
# and          	✓            	I-AUTHOR	I-AUTHOR
# P            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Schulthess   	✓            	I-AUTHOR	I-AUTHOR
# ,            	✓            	B-PUNC  	B-PUNC
# (            	✓            	B-PUNC  	B-PUNC
# 1995         	✓            	B-DATE  	B-DATE
# )            	✓            	B-PUNC  	B-PUNC
# Multimedia   	             	B-TITLE 	B-TITLE
# Application  	             	I-TITLE 	I-TITLE
# Sharing      	             	I-TITLE 	I-TITLE
# in           	             	I-TITLE 	I-TITLE
# a            	✓            	I-TITLE 	I-TITLE
# Heterogeneous	             	I-TITLE 	I-TITLE
# Environment  	             	I-TITLE 	I-TITLE
# ,            	✓            	B-PUNC  	B-PUNC
# ACM          	             	B-CT    	B-CT
# Multimedia   	             	I-CT    	I-CT
# 95           	✓            	B-VOL   	I-CT
# ,            	✓            	B-PUNC  	B-PUNC
# 57           	✓            	B-PAGE  	B-PAGE
# -            	✓            	B-PUNC  	B-PUNC
# 64           	✓            	I-PAGE  	I-PAGE
#
# word         	unk          	pred tag	true tag
# W            	             	B-AUTHOR	B-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Li           	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Linearly     	             	B-TITLE 	B-TITLE
# convergent   	             	I-TITLE 	I-TITLE
# descent      	             	I-TITLE 	I-TITLE
# methods      	             	I-TITLE 	I-TITLE
# for          	             	I-TITLE 	I-TITLE
# unconstrained	             	I-TITLE 	I-TITLE
# minimization 	             	I-TITLE 	I-TITLE
# of           	✓            	I-TITLE 	I-TITLE
# convex       	             	I-TITLE 	I-TITLE
# quadratic    	             	I-TITLE 	I-TITLE
# splines      	             	I-TITLE 	I-TITLE
# .            	✓            	B-PUNC  	B-PUNC
# 1993         	✓            	B-DATE  	B-DATE
# .            	✓            	B-PUNC  	B-PUNC
# Journal      	             	B-CT    	B-CT
# of           	✓            	I-CT    	I-CT
# Optimization 	             	I-CT    	I-CT
# Theory       	             	I-CT    	I-CT
# and          	✓            	I-CT    	I-CT
# Applications 	             	I-CT    	I-CT
# ,            	✓            	B-PUNC  	B-PUNC
#
# word          	unk           	pred tag	true tag
# Litman        	✓             	B-AUTHOR	B-AUTHOR
# ,             	✓             	B-PUNC  	B-PUNC
# D             	              	I-AUTHOR	I-AUTHOR
# .             	✓             	B-PUNC  	B-PUNC
# ,             	✓             	B-PUNC  	B-PUNC
# &             	              	B-PUNC  	B-PUNC
# Hirschberg    	✓             	I-AUTHOR	I-AUTHOR
# ,             	✓             	B-PUNC  	B-PUNC
# J             	              	I-AUTHOR	I-AUTHOR
# .             	✓             	B-PUNC  	B-PUNC
# (             	✓             	B-PUNC  	B-PUNC
# 1990          	✓             	B-DATE  	B-DATE
# )             	✓             	B-PUNC  	B-PUNC
# .             	✓             	B-PUNC  	B-PUNC
# Disambiguating	✓             	B-TITLE 	B-TITLE
# cue           	              	I-TITLE 	I-TITLE
# phrases       	              	I-TITLE 	I-TITLE
# in            	              	I-TITLE 	I-TITLE
# text          	              	I-TITLE 	I-TITLE
# and           	✓             	I-TITLE 	I-TITLE
# speech        	              	I-TITLE 	I-TITLE
# .             	✓             	B-PUNC  	B-PUNC
# In            	              	O       	B-CT
# Proceedings   	              	B-CT    	I-CT
# of            	✓             	I-CT    	I-CT
# the           	              	I-CT    	I-CT
# Thirteenth    	              	I-CT    	I-CT
# International 	              	I-CT    	I-CT
# Conference    	              	I-CT    	I-CT
# on            	              	I-CT    	I-CT
# Computational 	              	I-CT    	I-CT
# Linguistics   	              	I-CT    	I-CT
# (             	✓             	B-PUNC  	B-PUNC
# COLING        	✓             	I-CT    	I-CT
# )             	✓             	B-PUNC  	B-PUNC
# .             	✓             	B-PUNC  	B-PUNC
#
# word         	unk          	pred tag	true tag
# Narayana     	✓            	B-AUTHOR	B-AUTHOR
# ,            	✓            	B-PUNC  	B-PUNC
# K            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# T            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# and          	✓            	I-AUTHOR	I-AUTHOR
# Aaby         	✓            	I-AUTHOR	I-AUTHOR
# ,            	✓            	B-PUNC  	B-PUNC
# A            	✓            	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# A            	✓            	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# ,            	✓            	B-PUNC  	B-PUNC
# "            	✓            	B-PUNC  	B-PUNC
# Specification	             	I-TITLE 	B-TITLE
# of           	✓            	I-TITLE 	I-TITLE
# Real         	             	I-TITLE 	I-TITLE
# -            	✓            	B-PUNC  	B-PUNC
# Time         	             	I-TITLE 	I-TITLE
# Systems      	             	I-TITLE 	I-TITLE
# in           	             	I-TITLE 	I-TITLE
# Real         	             	I-TITLE 	I-TITLE
# -            	✓            	B-PUNC  	B-PUNC
# Time         	             	I-TITLE 	I-TITLE
# Temporal     	             	I-TITLE 	I-TITLE
# Interval     	             	I-TITLE 	I-TITLE
# Logic        	             	I-TITLE 	I-TITLE
# "            	✓            	B-PUNC  	B-PUNC
# ,            	✓            	B-PUNC  	B-PUNC
# Proceedings  	             	B-CT    	B-CT
# of           	✓            	I-CT    	I-CT
# Real         	             	I-CT    	I-CT
# -            	✓            	B-PUNC  	B-PUNC
# Time         	             	I-CT    	I-CT
# Systems      	             	I-CT    	I-CT
# Symposium    	             	I-CT    	I-CT
# ,            	✓            	B-PUNC  	B-PUNC
# December     	             	B-DATE  	B-DATE
# 1988         	✓            	I-DATE  	I-DATE
# .            	✓            	B-PUNC  	B-PUNC
#
# word           	unk            	pred tag	true tag
# U              	               	B-AUTHOR	B-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# Kremer         	✓              	I-AUTHOR	I-AUTHOR
# ,              	✓              	B-PUNC  	B-PUNC
# H              	               	I-AUTHOR	I-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# Zima           	✓              	I-AUTHOR	I-AUTHOR
# ,              	✓              	B-PUNC  	B-PUNC
# H              	               	I-AUTHOR	I-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# -              	✓              	B-PUNC  	B-PUNC
# J              	               	I-AUTHOR	I-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# Bast           	               	I-AUTHOR	I-AUTHOR
# ,              	✓              	B-PUNC  	B-PUNC
# and            	✓              	I-AUTHOR	I-AUTHOR
# M              	               	I-AUTHOR	I-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# Gerndt         	✓              	I-AUTHOR	I-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# Advanced       	               	B-TITLE 	B-TITLE
# tools          	               	I-TITLE 	I-TITLE
# and            	✓              	I-TITLE 	I-TITLE
# techniques     	               	I-TITLE 	I-TITLE
# for            	               	I-TITLE 	I-TITLE
# automatic      	               	I-TITLE 	I-TITLE
# parallelization	               	I-TITLE 	I-TITLE
# .              	✓              	B-PUNC  	B-PUNC
# Parallel       	               	B-CT    	B-CT
# Computing      	               	I-CT    	I-CT
# ,              	✓              	B-PUNC  	B-PUNC
# 7              	               	B-VOL   	B-VOL
# 387            	✓              	B-PAGE  	B-PAGE
# -              	✓              	B-PUNC  	B-PUNC
# 393            	✓              	I-PAGE  	I-PAGE
# 1988           	✓              	B-DATE  	B-DATE
# .              	✓              	B-PUNC  	B-PUNC
#
# word       	unk        	pred tag	true tag
# Allen      	           	B-AUTHOR	B-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# James      	           	I-AUTHOR	I-AUTHOR
# F          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# (          	✓          	B-PUNC  	B-PUNC
# 1979       	✓          	B-DATE  	B-DATE
# )          	✓          	B-PUNC  	B-PUNC
# .          	✓          	B-PUNC  	B-PUNC
# A          	✓          	B-TITLE 	B-TITLE
# Plan       	           	I-TITLE 	I-TITLE
# -          	✓          	B-PUNC  	B-PUNC
# Based      	           	I-TITLE 	I-TITLE
# Approach   	           	I-TITLE 	I-TITLE
# to         	✓          	I-TITLE 	I-TITLE
# Speech     	           	I-TITLE 	I-TITLE
# Act        	           	I-TITLE 	I-TITLE
# Recognition	           	I-TITLE 	I-TITLE
# .          	✓          	B-PUNC  	B-PUNC
#
# word       	unk        	pred tag	true tag
# L          	           	B-AUTHOR	B-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Lovasz     	✓          	I-AUTHOR	I-AUTHOR
# and        	✓          	I-AUTHOR	I-AUTHOR
# N          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Young      	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Lecture    	           	B-TITLE 	B-TITLE
# notes      	           	I-TITLE 	I-TITLE
# on         	           	I-TITLE 	I-TITLE
# evasiveness	           	I-TITLE 	I-TITLE
# of         	✓          	I-TITLE 	I-TITLE
# graph      	           	I-TITLE 	I-TITLE
# properties 	           	I-TITLE 	I-TITLE
# .          	✓          	B-PUNC  	B-PUNC
# 1991       	✓          	B-DATE  	B-DATE
# .          	✓          	B-PUNC  	B-PUNC
#
# word       	unk        	pred tag	true tag
# J          	           	B-AUTHOR	B-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# J          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Koenderink 	✓          	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# The        	           	B-TITLE 	B-TITLE
# structure  	           	I-TITLE 	I-TITLE
# of         	✓          	I-TITLE 	I-TITLE
# images     	           	I-TITLE 	I-TITLE
# .          	✓          	B-PUNC  	B-PUNC
# Biological 	           	B-CT    	B-CT
# Cybernetics	           	I-CT    	I-CT
# ,          	✓          	B-PUNC  	B-PUNC
# 50         	✓          	B-VOL   	B-VOL
# 363        	✓          	B-PAGE  	B-PAGE
# -          	✓          	B-PUNC  	B-PUNC
# 396        	✓          	I-PAGE  	I-PAGE
# 1984       	✓          	B-DATE  	B-DATE
# .          	✓          	B-PUNC  	B-PUNC
#
# word        	unk         	pred tag	true tag
# Jaswinder   	✓           	B-AUTHOR	B-AUTHOR
# Pal         	            	I-AUTHOR	I-AUTHOR
# Singh       	            	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# Wolf        	            	I-AUTHOR	I-AUTHOR
# -           	✓           	B-PUNC  	B-PUNC
# Dietrich    	✓           	I-AUTHOR	I-AUTHOR
# Weber       	            	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# and         	✓           	I-AUTHOR	I-AUTHOR
# Anoop       	✓           	I-AUTHOR	I-AUTHOR
# Gupta       	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# SPLASH      	            	B-TITLE 	B-TITLE
# :           	✓           	B-PUNC  	B-PUNC
# Stanford    	            	I-TITLE 	I-TITLE
# Parallel    	            	I-TITLE 	I-TITLE
# Applications	            	I-TITLE 	I-TITLE
# for         	            	I-TITLE 	I-TITLE
# Shared      	            	I-TITLE 	I-TITLE
# Memory      	            	I-TITLE 	I-TITLE
# .           	✓           	B-PUNC  	B-PUNC
# Computer    	            	B-CT    	B-CT
# Architecture	            	I-CT    	I-CT
# News        	            	I-CT    	I-CT
# ,           	✓           	B-PUNC  	B-PUNC
# 20          	✓           	B-VOL   	B-VOL
# (           	✓           	B-PUNC  	B-PUNC
# 1           	            	B-ISSUE 	I-VOL
# )           	✓           	B-PUNC  	B-PUNC
# ,           	✓           	B-PUNC  	B-PUNC
# 5           	            	B-PAGE  	B-PAGE
# -           	✓           	B-PUNC  	B-PUNC
# 44          	✓           	I-DATE  	I-PAGE
# March       	            	I-DATE  	B-DATE
# 1992        	✓           	I-DATE  	I-DATE
# .           	✓           	B-PUNC  	B-PUNC
#
# word       	unk        	pred tag	true tag
# Quinlan    	✓          	B-AUTHOR	B-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# J          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# R          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# (          	✓          	B-PUNC  	B-PUNC
# 1990       	✓          	B-DATE  	B-DATE
# )          	✓          	B-PUNC  	B-PUNC
# .          	✓          	B-PUNC  	B-PUNC
# Learning   	           	B-TITLE 	B-TITLE
# logical    	           	I-TITLE 	I-TITLE
# definitions	           	I-TITLE 	I-TITLE
# from       	           	I-TITLE 	I-TITLE
# relations  	           	I-TITLE 	I-TITLE
# .          	✓          	B-PUNC  	B-PUNC
# Machine    	           	B-CT    	B-CT
# Learning   	           	I-CT    	I-CT
# ,          	✓          	B-PUNC  	B-PUNC
# 5          	           	B-VOL   	B-VOL
# ,          	✓          	B-PUNC  	B-PUNC
# 239        	✓          	B-PAGE  	B-PAGE
# -          	✓          	B-PUNC  	B-PUNC
# 266        	✓          	I-PAGE  	I-PAGE
#
# word       	unk        	pred tag	true tag
# Knopfmacher	✓          	B-AUTHOR	B-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# A          	✓          	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# On         	           	B-TITLE 	B-TITLE
# the        	           	I-TITLE 	I-TITLE
# number     	           	I-TITLE 	I-TITLE
# of         	✓          	I-TITLE 	I-TITLE
# distinct   	           	I-TITLE 	I-TITLE
# degree     	           	I-TITLE 	I-TITLE
# sizes      	           	I-TITLE 	I-TITLE
# of         	✓          	I-TITLE 	I-TITLE
# a          	✓          	I-TITLE 	I-TITLE
# polynomial 	           	I-TITLE 	I-TITLE
# over       	           	I-TITLE 	I-TITLE
# a          	✓          	I-TITLE 	I-TITLE
# finite     	           	I-TITLE 	I-TITLE
# field      	           	I-TITLE 	I-TITLE
# .          	✓          	B-PUNC  	B-PUNC
# 1996       	✓          	B-DATE  	B-DATE
# .          	✓          	B-PUNC  	B-PUNC
#
# word         	unk          	pred tag	true tag
# Cohen        	             	B-AUTHOR	B-AUTHOR
# ,            	✓            	B-PUNC  	B-PUNC
# W            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# W            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# (            	✓            	B-PUNC  	B-PUNC
# 1992         	✓            	B-DATE  	B-DATE
# )            	✓            	B-PUNC  	B-PUNC
# .            	✓            	B-PUNC  	B-PUNC
# Compiling    	             	B-TITLE 	B-TITLE
# knowledge    	             	I-TITLE 	I-TITLE
# into         	             	I-TITLE 	I-TITLE
# an           	             	I-TITLE 	I-TITLE
# explicit     	             	I-TITLE 	I-TITLE
# bias         	             	I-TITLE 	I-TITLE
# .            	✓            	B-PUNC  	B-PUNC
# In           	             	O       	B-CT
# Proceedings  	             	B-CT    	I-CT
# of           	✓            	I-CT    	I-CT
# the          	             	I-CT    	I-CT
# Ninth        	             	I-CT    	I-CT
# International	             	I-CT    	I-CT
# Conference   	             	I-CT    	I-CT
# on           	             	I-CT    	I-CT
# Machine      	             	I-CT    	I-CT
# Learning     	             	I-CT    	I-CT
# .            	✓            	B-PUNC  	B-PUNC
#
# word      	unk       	pred tag   	true tag
# Spirtes   	✓         	B-AUTHOR   	B-AUTHOR
# ,         	✓         	B-PUNC     	B-PUNC
# P         	          	I-AUTHOR   	I-AUTHOR
# .         	✓         	B-PUNC     	B-PUNC
# ,         	✓         	B-PUNC     	B-PUNC
# Glymour   	✓         	I-AUTHOR   	I-AUTHOR
# ,         	✓         	B-PUNC     	B-PUNC
# C         	          	I-AUTHOR   	I-AUTHOR
# .         	✓         	B-PUNC     	B-PUNC
# ,         	✓         	B-PUNC     	B-PUNC
# &         	          	B-PUNC     	B-PUNC
# Scheines  	✓         	I-AUTHOR   	I-AUTHOR
# ,         	✓         	B-PUNC     	B-PUNC
# R         	          	I-AUTHOR   	I-AUTHOR
# .         	✓         	B-PUNC     	B-PUNC
# (         	✓         	B-PUNC     	B-PUNC
# 1993      	✓         	B-DATE     	B-DATE
# )         	✓         	B-PUNC     	B-PUNC
# .         	✓         	B-PUNC     	B-PUNC
# Causation 	          	B-TITLE    	B-TITLE
# ,         	✓         	B-PUNC     	B-PUNC
# Prediction	          	I-CT       	I-TITLE
# ,         	✓         	B-PUNC     	B-PUNC
# and       	✓         	I-CT       	I-TITLE
# Search    	          	I-CT       	I-TITLE
# .         	✓         	B-PUNC     	B-PUNC
# Springer  	          	B-PUBLISHER	B-PUBLISHER
# -         	✓         	B-PUNC     	B-PUNC
# Verlag    	✓         	I-PUBLISHER	I-PUBLISHER
# ,         	✓         	B-PUNC     	B-PUNC
#
# word         	unk          	pred tag	true tag
# B            	             	B-AUTHOR	B-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Shneiderman  	✓            	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Tree         	             	B-TITLE 	B-TITLE
# visualization	             	I-TITLE 	I-TITLE
# with         	             	I-TITLE 	I-TITLE
# tree         	             	I-TITLE 	I-TITLE
# -            	✓            	B-PUNC  	B-PUNC
# maps         	             	I-TITLE 	I-TITLE
# :            	✓            	B-PUNC  	B-PUNC
# A            	✓            	I-TITLE 	I-TITLE
# 2            	             	I-TITLE 	I-TITLE
# -            	✓            	B-PUNC  	B-PUNC
# d            	             	I-TITLE 	I-TITLE
# space        	             	I-TITLE 	I-TITLE
# filling      	             	I-TITLE 	I-TITLE
# approach     	             	I-TITLE 	I-TITLE
# .            	✓            	B-PUNC  	B-PUNC
# ACM          	             	B-CT    	B-CT
# Transactions 	             	I-CT    	I-CT
# on           	             	I-CT    	I-CT
# Graphics     	             	I-CT    	I-CT
# ,            	✓            	B-PUNC  	B-PUNC
# 11           	✓            	B-VOL   	B-VOL
# (            	✓            	B-PUNC  	B-PUNC
# 1            	             	B-ISSUE 	I-VOL
# )            	✓            	B-PUNC  	B-PUNC
# 1            	             	I-DATE  	B-PAGE
# -            	✓            	B-PUNC  	B-PUNC
# 39           	✓            	I-PAGE  	I-PAGE
# Jan          	             	I-DATE  	B-DATE
# .            	✓            	B-PUNC  	B-PUNC
# 1992         	✓            	I-DATE  	I-DATE
# .            	✓            	B-PUNC  	B-PUNC
#
# word       	unk        	pred tag	true tag
# Flanagan   	           	B-AUTHOR	B-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# C          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# ,          	✓          	B-PUNC  	B-PUNC
# and        	✓          	I-AUTHOR	I-AUTHOR
# Felleisen  	✓          	I-AUTHOR	I-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# M          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Modular    	           	B-TITLE 	B-TITLE
# and        	✓          	I-TITLE 	I-TITLE
# polymorphic	           	I-TITLE 	I-TITLE
# set        	           	I-TITLE 	I-TITLE
# -          	✓          	B-PUNC  	B-PUNC
# based      	           	I-TITLE 	I-TITLE
# analysis   	           	I-TITLE 	I-TITLE
# :          	✓          	B-PUNC  	B-PUNC
# Theory     	           	I-TITLE 	I-TITLE
# and        	✓          	I-TITLE 	I-TITLE
# practice   	           	I-TITLE 	I-TITLE
# .          	✓          	B-PUNC  	B-PUNC
# 1996       	✓          	B-DATE  	B-DATE
# .          	✓          	B-PUNC  	B-PUNC
#
# word       	unk        	pred tag	true tag
# Quinlan    	✓          	B-AUTHOR	B-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# J          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# R          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# ,          	✓          	B-PUNC  	B-PUNC
# &          	           	B-PUNC  	B-PUNC
# Cameron    	           	I-AUTHOR	I-AUTHOR
# -          	✓          	B-PUNC  	B-PUNC
# Jones      	           	I-AUTHOR	I-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# R          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# M          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# (          	✓          	B-PUNC  	B-PUNC
# 1993       	✓          	B-DATE  	B-DATE
# )          	✓          	B-PUNC  	B-PUNC
# .          	✓          	B-PUNC  	B-PUNC
# FOIL       	           	B-TITLE 	B-TITLE
# :          	✓          	B-PUNC  	B-PUNC
# A          	✓          	I-TITLE 	I-TITLE
# midterm    	           	I-TITLE 	I-TITLE
# report     	           	I-TITLE 	I-TITLE
# .          	✓          	B-PUNC  	B-PUNC
# In         	           	O       	B-CT
# Proceedings	           	B-CT    	I-CT
# of         	✓          	I-CT    	I-CT
# the        	           	I-CT    	I-CT
# European   	           	I-CT    	I-CT
# Conference 	           	I-CT    	I-CT
# on         	           	I-CT    	I-CT
# Machine    	           	I-CT    	I-CT
# Learning   	           	I-CT    	I-CT
# ,          	✓          	B-PUNC  	B-PUNC
# 3          	           	B-PAGE  	B-PAGE
# -          	✓          	B-PUNC  	B-PUNC
# 20         	✓          	I-PAGE  	I-PAGE
#
# word        	unk         	pred tag	true tag
# Ruth        	            	B-AUTHOR	B-AUTHOR
# Shapira     	✓           	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# A           	✓           	B-TITLE 	B-TITLE
# note        	            	I-TITLE 	I-TITLE
# on          	            	I-TITLE 	I-TITLE
# Sugihara    	✓           	I-TITLE 	I-TITLE
# '           	✓           	B-PUNC  	B-PUNC
# s           	            	I-TITLE 	I-TITLE
# claim       	            	I-TITLE 	I-TITLE
# .           	✓           	B-PUNC  	B-PUNC
# IEEE        	            	B-CT    	B-CT
# Transactions	            	I-CT    	I-CT
# on          	            	I-CT    	I-CT
# Pattern     	            	I-CT    	I-CT
# Analysis    	            	I-CT    	I-CT
# and         	✓           	I-CT    	I-CT
# Machine     	            	I-CT    	I-CT
# Intelligence	            	I-CT    	I-CT
# ,           	✓           	B-PUNC  	B-PUNC
# 6           	            	B-VOL   	B-VOL
# (           	✓           	B-PUNC  	B-PUNC
# 1           	            	B-ISSUE 	I-VOL
# )           	✓           	B-PUNC  	B-PUNC
# 122         	✓           	B-PAGE  	B-PAGE
# -           	✓           	B-PUNC  	B-PUNC
# 123         	✓           	I-PAGE  	I-PAGE
# 1984        	✓           	B-DATE  	B-DATE
# .           	✓           	B-PUNC  	B-PUNC
#
# word     	unk      	pred tag	true tag
# Pagallo  	✓        	B-AUTHOR	B-AUTHOR
# ,        	✓        	B-PUNC  	B-PUNC
# G        	         	I-AUTHOR	I-AUTHOR
# .        	✓        	B-PUNC  	B-PUNC
# ,        	✓        	B-PUNC  	B-PUNC
# &        	         	B-PUNC  	B-PUNC
# Haussler 	✓        	I-AUTHOR	I-AUTHOR
# ,        	✓        	B-PUNC  	B-PUNC
# D        	         	I-AUTHOR	I-AUTHOR
# .        	✓        	B-PUNC  	B-PUNC
# (        	✓        	B-PUNC  	B-PUNC
# 1990     	✓        	B-DATE  	B-DATE
# )        	✓        	B-PUNC  	B-PUNC
# .        	✓        	B-PUNC  	B-PUNC
# Boolean  	         	B-TITLE 	B-TITLE
# feature  	         	I-TITLE 	I-TITLE
# discovery	         	I-TITLE 	I-TITLE
# in       	         	I-TITLE 	I-TITLE
# empirical	         	I-TITLE 	I-TITLE
# learning 	         	I-TITLE 	I-TITLE
# .        	✓        	B-PUNC  	B-PUNC
# Machine  	         	B-CT    	B-CT
# Learning 	         	I-CT    	I-CT
# ,        	✓        	B-PUNC  	B-PUNC
# 5        	         	B-VOL   	B-VOL
# (        	✓        	B-PUNC  	B-PUNC
# 1        	         	B-ISSUE 	I-VOL
# )        	✓        	B-PUNC  	B-PUNC
# ,        	✓        	B-PUNC  	B-PUNC
# 71       	✓        	B-PAGE  	B-PAGE
# -        	✓        	B-PUNC  	B-PUNC
# 99       	✓        	I-PAGE  	I-PAGE
#
# word       	unk        	pred tag	true tag
# Report     	           	B-TITLE	B-TITLE
# on         	           	I-TITLE	I-TITLE
# the        	           	I-TITLE	I-TITLE
# Programming	           	I-TITLE	I-TITLE
# Language   	           	I-TITLE	I-TITLE
# Haskell    	✓          	I-TITLE	I-TITLE
# ,          	✓          	B-PUNC 	B-PUNC
# version    	           	I-TITLE	I-TITLE
# 1          	           	I-TITLE	I-TITLE
# .          	✓          	B-PUNC 	B-PUNC
# 2          	           	I-TITLE	I-TITLE
# .          	✓          	B-PUNC 	B-PUNC
# ACM        	           	B-CT   	B-CT
# SIGPLAN    	✓          	I-CT   	I-CT
# Notices    	           	I-CT   	I-CT
# ,          	✓          	B-PUNC 	B-PUNC
# 27         	✓          	B-VOL  	B-VOL
# (          	✓          	B-PUNC 	B-PUNC
# 5          	           	B-ISSUE	I-VOL
# )          	✓          	B-PUNC 	B-PUNC
# ,          	✓          	B-PUNC 	B-PUNC
# 1992       	✓          	B-DATE 	B-DATE
# .          	✓          	B-PUNC 	B-PUNC
#
# word        	unk         	pred tag	true tag
# David       	            	B-AUTHOR	B-AUTHOR
# Chapman     	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Planning    	            	B-TITLE 	B-TITLE
# for         	            	I-TITLE 	I-TITLE
# conjunctive 	            	I-TITLE 	I-TITLE
# goals       	            	I-TITLE 	I-TITLE
# .           	✓           	B-PUNC  	B-PUNC
# Artificial  	            	B-CT    	B-CT
# Intelligence	            	I-CT    	I-CT
# ,           	✓           	B-PUNC  	B-PUNC
# 32          	✓           	B-VOL   	B-VOL
# ,           	✓           	B-PUNC  	B-PUNC
# 1987        	✓           	B-PAGE  	B-DATE
# .           	✓           	B-PUNC  	B-PUNC
#
# word     	unk      	pred tag   	true tag
# Topics   	         	B-TITLE    	B-TITLE
# in       	         	O          	I-TITLE
# Case     	         	B-CT       	I-TITLE
# -        	✓        	B-PUNC     	B-PUNC
# Based    	         	I-CT       	I-TITLE
# Reasoning	         	I-CT       	I-TITLE
# .        	✓        	B-PUNC     	B-PUNC
# Springer 	         	B-PUBLISHER	B-PUBLISHER
# -        	✓        	B-PUNC     	B-PUNC
# Verlag   	✓        	I-PUBLISHER	I-PUBLISHER
# ,        	✓        	B-PUNC     	B-PUNC
# 167      	✓        	B-PAGE     	B-PAGE
# -        	✓        	B-PUNC     	B-PUNC
# 181      	✓        	I-PAGE     	I-PAGE
#
# word       	unk        	pred tag	true tag
# Ramadge    	✓          	B-AUTHOR	B-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# P          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# ,          	✓          	B-PUNC  	B-PUNC
# &          	           	B-PUNC  	B-PUNC
# Wonham     	✓          	I-AUTHOR	I-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# W          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# (          	✓          	B-PUNC  	B-PUNC
# 1989       	✓          	B-DATE  	B-DATE
# )          	✓          	B-PUNC  	B-PUNC
# .          	✓          	B-PUNC  	B-PUNC
# The        	           	B-TITLE 	B-TITLE
# Control    	           	I-TITLE 	I-TITLE
# of         	✓          	I-TITLE 	I-TITLE
# Discrete   	           	I-TITLE 	I-TITLE
# Event      	           	I-TITLE 	I-TITLE
# Systems    	           	I-TITLE 	I-TITLE
# .          	✓          	B-PUNC  	B-PUNC
# Proceedings	           	B-CT    	B-CT
# of         	✓          	I-CT    	I-CT
# the        	           	I-CT    	I-CT
# IEEE       	           	I-CT    	I-CT
# ,          	✓          	B-PUNC  	B-PUNC
# 77         	✓          	B-VOL   	B-VOL
# (          	✓          	B-PUNC  	B-PUNC
# 1          	           	B-ISSUE 	I-VOL
# )          	✓          	B-PUNC  	B-PUNC
# ,          	✓          	B-PUNC  	B-PUNC
# 81         	✓          	B-PAGE  	B-PAGE
# -          	✓          	B-PUNC  	B-PUNC
# 98         	✓          	I-PAGE  	I-PAGE
#
# word         	unk          	pred tag   	true tag
# Thrun        	✓            	B-AUTHOR   	B-AUTHOR
# ,            	✓            	B-PUNC     	B-PUNC
# T            	             	I-AUTHOR   	I-AUTHOR
# .            	✓            	B-PUNC     	B-PUNC
# ,            	✓            	B-PUNC     	B-PUNC
# Schwartz     	             	I-AUTHOR   	I-AUTHOR
# ,            	✓            	B-PUNC     	B-PUNC
# A            	✓            	I-AUTHOR   	I-AUTHOR
# .            	✓            	B-PUNC     	B-PUNC
# (            	✓            	B-PUNC     	B-PUNC
# 1995         	✓            	B-DATE     	B-DATE
# )            	✓            	B-PUNC     	B-PUNC
# "            	✓            	B-PUNC     	B-PUNC
# Finding      	             	B-TITLE    	B-TITLE
# Structure    	             	I-TITLE    	I-TITLE
# in           	             	I-TITLE    	I-TITLE
# Reinforcement	             	I-TITLE    	I-TITLE
# Learning     	             	I-TITLE    	I-TITLE
# ,            	✓            	B-PUNC     	B-PUNC
# "            	✓            	B-PUNC     	B-PUNC
# in           	             	O          	B-CT
# Advances     	             	B-CT       	I-CT
# in           	             	I-CT       	I-CT
# Neural       	             	I-CT       	I-CT
# Information  	             	I-CT       	I-CT
# Processing   	             	I-CT       	I-CT
# Systems      	             	I-CT       	I-CT
# ,            	✓            	B-PUNC     	B-PUNC
# 7            	             	B-PAGE     	I-CT
# .            	✓            	B-PUNC     	B-PUNC
# Morgan       	             	B-PUBLISHER	B-PUBLISHER
# Kaufmann     	✓            	I-PUBLISHER	I-PUBLISHER
# .            	✓            	B-PUNC     	B-PUNC
#
# word       	unk        	pred tag	true tag
# M          	           	B-AUTHOR	B-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Herlihy    	✓          	I-AUTHOR	I-AUTHOR
# and        	✓          	I-AUTHOR	I-AUTHOR
# J          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Wing       	           	I-AUTHOR	I-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# "          	✓          	B-PUNC  	B-PUNC
# Axioms     	           	I-TITLE 	B-TITLE
# for        	           	I-TITLE 	I-TITLE
# Concurrent 	           	I-TITLE 	I-TITLE
# Objects    	           	I-TITLE 	I-TITLE
# "          	✓          	B-PUNC  	B-PUNC
# ,          	✓          	B-PUNC  	B-PUNC
# Proceedings	           	B-CT    	B-CT
# of         	✓          	I-CT    	I-CT
# the        	           	I-CT    	I-CT
# 14th       	✓          	I-CT    	I-CT
# ACM        	           	I-CT    	I-CT
# Symposium  	           	I-CT    	I-CT
# on         	           	I-CT    	I-CT
# Principles 	           	I-CT    	I-CT
# of         	✓          	I-CT    	I-CT
# Programming	           	I-CT    	I-CT
# Languages  	           	I-CT    	I-CT
# ,          	✓          	B-PUNC  	B-PUNC
# 13         	✓          	B-DATE  	B-PAGE
# -          	✓          	B-PUNC  	B-PUNC
# 26         	✓          	I-PAGE  	I-PAGE
# 1987       	✓          	B-DATE  	B-DATE
# .          	✓          	B-PUNC  	B-PUNC
#
# word         	unk          	pred tag   	true tag
# J            	             	B-AUTHOR   	B-AUTHOR
# .            	✓            	B-PUNC     	B-PUNC
# E            	             	I-AUTHOR   	I-AUTHOR
# .            	✓            	B-PUNC     	B-PUNC
# Dennis       	             	I-AUTHOR   	I-AUTHOR
# and          	✓            	I-AUTHOR   	I-AUTHOR
# R            	             	I-AUTHOR   	I-AUTHOR
# .            	✓            	B-PUNC     	B-PUNC
# B            	             	I-AUTHOR   	I-AUTHOR
# .            	✓            	B-PUNC     	B-PUNC
# Schnabel     	✓            	I-AUTHOR   	I-AUTHOR
# .            	✓            	B-PUNC     	B-PUNC
# Numerical    	             	I-TITLE    	B-TITLE
# Methods      	             	I-TITLE    	I-TITLE
# for          	             	I-TITLE    	I-TITLE
# Unconstrained	             	I-TITLE    	I-TITLE
# Optimization 	             	I-TITLE    	I-TITLE
# and          	✓            	I-TITLE    	I-TITLE
# Nonlinear    	             	I-TITLE    	I-TITLE
# Equations    	             	I-TITLE    	I-TITLE
# .            	✓            	B-PUNC     	B-PUNC
# Prentice     	✓            	B-CT       	B-CT
# -            	✓            	B-PUNC     	B-PUNC
# Hall         	             	I-CT       	I-CT
# Series       	             	I-CT       	I-CT
# in           	             	I-CT       	I-CT
# Computational	             	I-CT       	I-CT
# Mathematics  	             	I-CT       	I-CT
# .            	✓            	B-PUNC     	B-PUNC
# Prentice     	✓            	B-PUBLISHER	B-PUBLISHER
# -            	✓            	B-PUNC     	B-PUNC
# Hall         	             	I-PUBLISHER	I-PUBLISHER
# ,            	✓            	B-PUNC     	B-PUNC
# Inc          	             	I-PUBLISHER	I-PUBLISHER
# ,            	✓            	B-PUNC     	B-PUNC
# 1983         	✓            	B-DATE     	B-DATE
# .            	✓            	B-PUNC     	B-PUNC
#
# word      	unk       	pred tag	true tag
# R         	          	B-AUTHOR	B-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# Fikes     	✓         	I-AUTHOR	I-AUTHOR
# ,         	✓         	B-PUNC  	B-PUNC
# M         	          	I-AUTHOR	I-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# Cutkosky  	✓         	I-AUTHOR	I-AUTHOR
# ,         	✓         	B-PUNC  	B-PUNC
# T         	          	I-AUTHOR	I-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# Gruber    	✓         	I-AUTHOR	I-AUTHOR
# ,         	✓         	B-PUNC  	B-PUNC
# and       	✓         	I-AUTHOR	I-AUTHOR
# J         	          	I-AUTHOR	I-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# V         	          	I-AUTHOR	I-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# Baalen    	✓         	I-AUTHOR	I-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# Knowledge 	          	B-CT    	B-TITLE
# Sharing   	          	I-CT    	I-TITLE
# Technology	          	I-CT    	I-TITLE
# Project   	          	I-CT    	I-TITLE
# Overview  	          	I-CT    	I-TITLE
# .         	✓         	B-PUNC  	B-PUNC
# 1991      	✓         	B-DATE  	B-DATE
# .         	✓         	B-PUNC  	B-PUNC
#
# word          	unk           	pred tag	true tag
# D             	              	B-AUTHOR	B-AUTHOR
# .             	✓             	B-PUNC  	B-PUNC
# Callahan      	✓             	I-AUTHOR	I-AUTHOR
# ,             	✓             	B-PUNC  	B-PUNC
# S             	              	I-AUTHOR	I-AUTHOR
# .             	✓             	B-PUNC  	B-PUNC
# Carr          	              	I-AUTHOR	I-AUTHOR
# ,             	✓             	B-PUNC  	B-PUNC
# and           	✓             	I-AUTHOR	I-AUTHOR
# K             	              	I-AUTHOR	I-AUTHOR
# .             	✓             	B-PUNC  	B-PUNC
# Kennedy       	              	I-AUTHOR	I-AUTHOR
# .             	✓             	B-PUNC  	B-PUNC
# Improving     	              	B-TITLE 	B-TITLE
# register      	              	I-TITLE 	I-TITLE
# allocation    	              	I-TITLE 	I-TITLE
# for           	              	I-TITLE 	I-TITLE
# subscripted   	✓             	I-TITLE 	I-TITLE
# variables     	              	I-TITLE 	I-TITLE
# .             	✓             	B-PUNC  	B-PUNC
# In            	              	O       	B-CT
# Proceedings   	              	B-CT    	I-CT
# of            	✓             	I-CT    	I-CT
# the           	              	I-CT    	I-CT
# SIGPLAN       	✓             	I-CT    	I-CT
# '             	✓             	B-PUNC  	B-PUNC
# 90            	✓             	I-CT    	I-CT
# Conference    	              	I-CT    	I-CT
# on            	              	I-CT    	I-CT
# Program       	              	I-CT    	I-CT
# Language      	              	I-CT    	I-CT
# Design        	              	I-CT    	I-CT
# and           	✓             	I-CT    	I-CT
# Implementation	              	I-CT    	I-CT
# ,             	✓             	B-PUNC  	B-PUNC
# June          	              	B-DATE  	B-DATE
# 1990          	✓             	I-DATE  	I-DATE
# .             	✓             	B-PUNC  	B-PUNC
#
# word      	unk       	pred tag   	true tag
# Geddes    	✓         	B-AUTHOR   	B-AUTHOR
# ,         	✓         	B-PUNC     	B-PUNC
# K         	          	I-AUTHOR   	I-AUTHOR
# .         	✓         	B-PUNC     	B-PUNC
# ,         	✓         	B-PUNC     	B-PUNC
# Czapor    	✓         	I-AUTHOR   	I-AUTHOR
# ,         	✓         	B-PUNC     	B-PUNC
# S         	          	I-AUTHOR   	I-AUTHOR
# .         	✓         	B-PUNC     	B-PUNC
# ,         	✓         	B-PUNC     	B-PUNC
# and       	✓         	I-AUTHOR   	I-AUTHOR
# Labahn    	✓         	I-AUTHOR   	I-AUTHOR
# ,         	✓         	B-PUNC     	B-PUNC
# G         	          	I-AUTHOR   	I-AUTHOR
# .         	✓         	B-PUNC     	B-PUNC
# Algorithms	          	B-TITLE    	B-TITLE
# for       	          	I-TITLE    	I-TITLE
# Computer  	          	I-TITLE    	I-TITLE
# Algebra   	          	I-TITLE    	I-TITLE
# .         	✓         	B-PUNC     	B-PUNC
# Kluwer    	✓         	B-PUBLISHER	B-PUBLISHER
# Academic  	          	I-PUBLISHER	I-PUBLISHER
# Publishers	          	I-PUBLISHER	I-PUBLISHER
# ,         	✓         	B-PUNC     	B-PUNC
# 1992      	✓         	B-DATE     	B-DATE
# .         	✓         	B-PUNC     	B-PUNC
#
# word          	unk           	pred tag   	true tag
# G             	              	B-AUTHOR   	B-AUTHOR
# .             	✓             	B-PUNC     	B-PUNC
# E             	              	I-AUTHOR   	I-AUTHOR
# .             	✓             	B-PUNC     	B-PUNC
# Blelloch      	✓             	I-AUTHOR   	I-AUTHOR
# ,             	✓             	B-PUNC     	B-PUNC
# S             	              	I-AUTHOR   	I-AUTHOR
# .             	✓             	B-PUNC     	B-PUNC
# Chatterjee    	              	I-AUTHOR   	I-AUTHOR
# ,             	✓             	B-PUNC     	B-PUNC
# J             	              	I-AUTHOR   	I-AUTHOR
# .             	✓             	B-PUNC     	B-PUNC
# C             	              	I-AUTHOR   	I-AUTHOR
# .             	✓             	B-PUNC     	B-PUNC
# Hardwick      	✓             	I-AUTHOR   	I-AUTHOR
# ,             	✓             	B-PUNC     	B-PUNC
# J             	              	I-AUTHOR   	I-AUTHOR
# .             	✓             	B-PUNC     	B-PUNC
# Sipelstein    	✓             	I-AUTHOR   	I-AUTHOR
# ,             	✓             	B-PUNC     	B-PUNC
# and           	✓             	I-AUTHOR   	I-AUTHOR
# M             	              	I-AUTHOR   	I-AUTHOR
# .             	✓             	B-PUNC     	B-PUNC
# Zagha         	✓             	I-AUTHOR   	I-AUTHOR
# .             	✓             	B-PUNC     	B-PUNC
# Implementation	              	B-TITLE    	B-TITLE
# of            	✓             	I-TITLE    	I-TITLE
# a             	✓             	I-TITLE    	I-TITLE
# portable      	              	I-TITLE    	I-TITLE
# nested        	              	I-TITLE    	I-TITLE
# data          	              	I-TITLE    	I-TITLE
# -             	✓             	B-PUNC     	B-PUNC
# parallel      	              	I-TITLE    	I-TITLE
# language      	              	I-TITLE    	I-TITLE
# .             	✓             	B-PUNC     	B-PUNC
# In            	              	O          	B-CT
# 4th           	              	B-CT       	I-CT
# Symposium     	              	I-CT       	I-CT
# on            	              	I-CT       	I-CT
# Principles    	              	I-CT       	I-CT
# and           	✓             	I-CT       	I-CT
# Practice      	              	I-CT       	I-CT
# of            	✓             	I-CT       	I-CT
# Parallel      	              	I-CT       	I-CT
# Programming   	              	I-CT       	I-CT
# .             	✓             	B-PUNC     	B-PUNC
# ACM           	              	B-PUBLISHER	I-CT
# SIGPLAN       	✓             	I-PUBLISHER	I-CT
# ,             	✓             	B-PUNC     	B-PUNC
# 1993          	✓             	B-DATE     	B-DATE
# .             	✓             	B-PUNC     	B-PUNC
#
# word           	unk            	pred tag	true tag
# Deutsch        	               	B-AUTHOR	B-AUTHOR
# ,              	✓              	B-PUNC  	B-PUNC
# A              	✓              	I-AUTHOR	I-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# Modeles        	✓              	B-TITLE 	B-TITLE
# Operationnels  	✓              	I-TITLE 	I-TITLE
# de             	               	I-TITLE 	I-TITLE
# Language       	               	I-TITLE 	I-TITLE
# de             	               	I-TITLE 	I-TITLE
# Programmation  	               	I-TITLE 	I-TITLE
# et             	               	I-TITLE 	I-TITLE
# Representations	               	I-TITLE 	I-TITLE
# de             	               	I-TITLE 	I-TITLE
# Relations      	               	I-TITLE 	I-TITLE
# sue            	               	I-TITLE 	I-TITLE
# des            	               	I-TITLE 	I-TITLE
# Languages      	               	I-TITLE 	I-TITLE
# Rationnels     	✓              	I-TITLE 	I-TITLE
# avec           	               	I-TITLE 	I-TITLE
# Application    	               	I-TITLE 	I-TITLE
# a              	✓              	I-TITLE 	I-TITLE
# la             	               	I-TITLE 	I-TITLE
# Determination  	               	I-TITLE 	I-TITLE
# Statique       	✓              	I-TITLE 	I-TITLE
# de             	               	I-TITLE 	I-TITLE
# Proprietes     	✓              	I-TITLE 	I-TITLE
# de             	               	I-TITLE 	I-TITLE
# Partages       	✓              	I-TITLE 	I-TITLE
# Dy             	               	I-TITLE 	I-TITLE
# -              	✓              	B-PUNC  	B-PUNC
# namiques       	✓              	I-TITLE 	I-TITLE
# de             	               	I-TITLE 	I-TITLE
# Donnees        	✓              	I-TITLE 	I-TITLE
# .              	✓              	B-PUNC  	B-PUNC
# 1992           	✓              	B-DATE  	B-DATE
# .              	✓              	B-PUNC  	B-PUNC
#
# word         	unk          	pred tag	true tag
# R            	             	B-AUTHOR	B-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# B            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Kieburtz     	✓            	I-AUTHOR	I-AUTHOR
# ,            	✓            	B-PUNC  	B-PUNC
# B            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Agapiev      	✓            	I-AUTHOR	I-AUTHOR
# and          	✓            	I-AUTHOR	I-AUTHOR
# J            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Hook         	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Three        	             	I-AUTHOR	B-TITLE
# Monads       	             	B-TITLE 	I-TITLE
# for          	             	I-TITLE 	I-TITLE
# Continuations	             	I-TITLE 	I-TITLE
# .            	✓            	B-PUNC  	B-PUNC
# In           	             	O       	B-CT
# Proceedings  	             	B-CT    	I-CT
# of           	✓            	I-CT    	I-CT
# the          	             	I-CT    	I-CT
# ACM          	             	I-CT    	I-CT
# SIGPLAN      	✓            	I-CT    	I-CT
# Workshop     	             	I-CT    	I-CT
# on           	             	I-CT    	I-CT
# Continuations	             	I-CT    	I-CT
# ,            	✓            	B-PUNC  	B-PUNC
# June         	             	B-DATE  	B-DATE
# 1992         	✓            	I-DATE  	I-DATE
# .            	✓            	B-PUNC  	B-PUNC
#
# word        	unk         	pred tag	true tag
# P           	            	B-AUTHOR	B-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# T           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Zellweger   	✓           	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Interactions	            	B-TITLE 	B-TITLE
# between     	            	I-TITLE 	I-TITLE
# high        	            	I-TITLE 	I-TITLE
# -           	✓           	B-PUNC  	B-PUNC
# level       	            	I-TITLE 	I-TITLE
# debugging   	            	I-TITLE 	I-TITLE
# and         	✓           	I-TITLE 	I-TITLE
# optimised   	✓           	I-TITLE 	I-TITLE
# code        	            	I-TITLE 	I-TITLE
# .           	✓           	B-PUNC  	B-PUNC
# 1984        	✓           	B-DATE  	B-DATE
# .           	✓           	B-PUNC  	B-PUNC
#
# word        	unk         	pred tag	true tag
# J           	            	B-AUTHOR	B-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Wiener      	            	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# H           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Gupta       	            	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# W           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Labio       	✓           	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# Y           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Zhuge       	✓           	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# H           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Garcia      	            	I-AUTHOR	I-AUTHOR
# -           	✓           	B-PUNC  	B-PUNC
# Molina      	✓           	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# and         	✓           	I-AUTHOR	I-AUTHOR
# J           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Widom       	✓           	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# A           	✓           	B-TITLE 	B-TITLE
# system      	            	I-TITLE 	I-TITLE
# prototype   	            	I-TITLE 	I-TITLE
# for         	            	I-TITLE 	I-TITLE
# warehouse   	            	I-TITLE 	I-TITLE
# view        	            	I-TITLE 	I-TITLE
# maintenance 	            	I-TITLE 	I-TITLE
# .           	✓           	B-PUNC  	B-PUNC
# In          	            	O       	B-CT
# The         	            	B-CT    	I-CT
# Workshop    	            	I-CT    	I-CT
# on          	            	I-CT    	I-CT
# Materialized	            	I-CT    	I-CT
# Views       	            	I-CT    	I-CT
# ,           	✓           	B-PUNC  	B-PUNC
# 26          	✓           	B-DATE  	B-PAGE
# -           	✓           	B-PUNC  	B-PUNC
# 33          	✓           	B-ISSUE 	I-PAGE
# June        	            	B-DATE  	B-DATE
# 1996        	✓           	I-DATE  	I-DATE
# .           	✓           	B-PUNC  	B-PUNC
#
# word      	unk       	pred tag	true tag
# Amdur     	✓         	B-AUTHOR	B-AUTHOR
# ,         	✓         	B-PUNC  	B-PUNC
# E         	          	I-AUTHOR	I-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# S         	          	I-AUTHOR	I-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# On        	          	B-TITLE 	B-TITLE
# the       	          	I-TITLE 	I-TITLE
# Message   	          	I-TITLE 	I-TITLE
# Complexity	          	I-TITLE 	I-TITLE
# of        	✓         	I-TITLE 	I-TITLE
# Byzantine 	          	I-TITLE 	I-TITLE
# Agreement 	          	I-TITLE 	I-TITLE
# .         	✓         	B-PUNC  	B-PUNC
# September 	          	B-DATE  	B-DATE
# 1988      	✓         	I-DATE  	I-DATE
# .         	✓         	B-PUNC  	B-PUNC
#
# word      	unk       	pred tag	true tag
# Reilly    	          	B-AUTHOR	B-AUTHOR
# ,         	✓         	B-PUNC  	B-PUNC
# W         	          	I-AUTHOR	I-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# S         	          	I-AUTHOR	I-AUTHOR
# .         	✓         	B-PUNC  	B-PUNC
# (         	✓         	B-PUNC  	B-PUNC
# 1996      	✓         	B-DATE  	B-DATE
# )         	✓         	B-PUNC  	B-PUNC
# .         	✓         	B-PUNC  	B-PUNC
# Believable	          	B-TITLE 	B-TITLE
# Emotional 	          	I-TITLE 	I-TITLE
# and       	✓         	I-TITLE 	I-TITLE
# Social    	          	I-TITLE 	I-TITLE
# Agents    	          	I-TITLE 	I-TITLE
# .         	✓         	B-PUNC  	B-PUNC
#
# word        	unk         	pred tag	true tag
# Strang      	✓           	B-AUTHOR	B-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# G           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# and         	✓           	I-AUTHOR	I-AUTHOR
# G           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# Fix         	            	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# A           	✓           	I-AUTHOR	B-TITLE
# Fourier     	            	B-TITLE 	I-TITLE
# analysis    	            	I-TITLE 	I-TITLE
# of          	✓           	I-TITLE 	I-TITLE
# the         	            	I-TITLE 	I-TITLE
# finite      	            	I-TITLE 	I-TITLE
# element     	            	I-TITLE 	I-TITLE
# variational 	            	I-TITLE 	I-TITLE
# method      	            	I-TITLE 	I-TITLE
# ,           	✓           	B-PUNC  	B-PUNC
# Constructive	            	B-CT    	I-TITLE
# Aspects     	            	I-CT    	I-TITLE
# of          	✓           	I-CT    	I-TITLE
# Functional  	            	I-CT    	I-TITLE
# Analysis    	            	I-CT    	I-TITLE
# C           	            	I-CT    	B-CT
# .           	✓           	B-PUNC  	B-PUNC
# I           	            	I-CT    	I-CT
# .           	✓           	B-PUNC  	B-PUNC
# M           	            	I-CT    	I-CT
# .           	✓           	B-PUNC  	B-PUNC
# E           	            	I-CT    	I-CT
# .           	✓           	B-PUNC  	B-PUNC
# ,           	✓           	B-PUNC  	B-PUNC
# 1973        	✓           	B-DATE  	B-DATE
# ,           	✓           	B-PUNC  	B-PUNC
# 793         	✓           	B-PAGE  	B-PAGE
# -           	✓           	B-PUNC  	B-PUNC
# 840         	✓           	I-PAGE  	I-PAGE
#
# word       	unk        	pred tag	true tag
# VanLehn    	✓          	B-AUTHOR	B-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# K          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# ,          	✓          	B-PUNC  	B-PUNC
# Jones      	           	I-AUTHOR	I-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# R          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# M          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# ...
# AAAI           	✓              	B-PUBLISHER	B-PUBLISHER
# Press          	               	I-PUBLISHER	I-PUBLISHER
# .              	✓              	B-PUNC     	B-PUNC
#
# word         	unk          	pred tag	true tag
# P            	             	B-AUTHOR	B-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Perez        	             	I-AUTHOR	I-AUTHOR
# and          	✓            	I-AUTHOR	I-AUTHOR
# F            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Heitz        	✓            	I-AUTHOR	I-AUTHOR
# ,            	✓            	B-PUNC  	B-PUNC
# "            	✓            	B-PUNC  	B-PUNC
# Multiscale   	             	B-TITLE 	B-TITLE
# Markov       	✓            	I-TITLE 	I-TITLE
# Random       	             	I-TITLE 	I-TITLE
# Fields       	             	I-TITLE 	I-TITLE
# and          	✓            	I-TITLE 	I-TITLE
# Constrained  	             	I-TITLE 	I-TITLE
# Relaxation   	             	I-TITLE 	I-TITLE
# in           	             	I-TITLE 	I-TITLE
# Low          	             	I-TITLE 	I-TITLE
# Level        	             	I-TITLE 	I-TITLE
# Image        	             	I-TITLE 	I-TITLE
# Analysis     	             	I-TITLE 	I-TITLE
# ,            	✓            	B-PUNC  	B-PUNC
# "            	✓            	B-PUNC  	B-PUNC
# IEEE         	             	B-CT    	B-CT
# International	             	I-CT    	I-CT
# Conf         	             	I-CT    	I-CT
# .            	✓            	B-PUNC  	B-PUNC
# on           	             	I-CT    	I-CT
# Acoustics    	             	I-CT    	I-CT
# ,            	✓            	B-PUNC  	B-PUNC
# Speech       	             	I-CT    	I-CT
# ,            	✓            	B-PUNC  	B-PUNC
# and          	✓            	I-CT    	I-CT
# Signal       	             	I-CT    	I-CT
# Processing   	             	I-CT    	I-CT
# ,            	✓            	B-PUNC  	B-PUNC
# Vol          	             	O       	B-VOL
# .            	✓            	B-PUNC  	B-PUNC
# 3            	             	B-VOL   	I-VOL
# ,            	✓            	B-PUNC  	B-PUNC
# 61           	✓            	B-PAGE  	B-PAGE
# -            	✓            	B-PUNC  	B-PUNC
# 64           	✓            	I-PAGE  	I-PAGE
# 1992         	✓            	B-DATE  	B-DATE
# .            	✓            	B-PUNC  	B-PUNC
#
# word            	unk             	pred tag	true tag
# Ling            	                	B-AUTHOR	B-AUTHOR
# Tony            	                	I-AUTHOR	I-AUTHOR
# Chen            	                	I-AUTHOR	I-AUTHOR
# ,               	✓               	B-PUNC  	B-PUNC
# R               	                	I-AUTHOR	I-AUTHOR
# .               	✓               	B-PUNC  	B-PUNC
# Drach           	✓               	I-AUTHOR	I-AUTHOR
# ,               	✓               	B-PUNC  	B-PUNC
# M               	                	I-AUTHOR	I-AUTHOR
# .               	✓               	B-PUNC  	B-PUNC
# Keating         	                	I-AUTHOR	I-AUTHOR
# ,               	✓               	B-PUNC  	B-PUNC
# S               	                	I-AUTHOR	I-AUTHOR
# .               	✓               	B-PUNC  	B-PUNC
# Louis           	                	I-AUTHOR	I-AUTHOR
# ,               	✓               	B-PUNC  	B-PUNC
# Doron           	✓               	I-AUTHOR	I-AUTHOR
# Rotem           	✓               	I-AUTHOR	I-AUTHOR
# ,               	✓               	B-PUNC  	B-PUNC
# Arie            	✓               	I-AUTHOR	I-AUTHOR
# Shoshani        	✓               	I-AUTHOR	I-AUTHOR
# ,               	✓               	B-PUNC  	B-PUNC
# Efficient       	                	B-TITLE 	B-TITLE
# organization    	                	I-TITLE 	I-TITLE
# and             	✓               	I-TITLE 	I-TITLE
# access          	                	I-TITLE 	I-TITLE
# of              	✓               	I-TITLE 	I-TITLE
# multidimensional	                	I-TITLE 	I-TITLE
# datasets        	                	I-TITLE 	I-TITLE
# on              	                	I-TITLE 	I-TITLE
# tertiary        	                	I-TITLE 	I-TITLE
# storage         	                	I-TITLE 	I-TITLE
# systems         	                	I-TITLE 	I-TITLE
# ,               	✓               	B-PUNC  	B-PUNC
# Information     	                	B-CT    	B-CT
# Systems         	                	I-CT    	I-CT
# 20              	✓               	B-VOL   	B-VOL
# (               	✓               	B-PUNC  	B-PUNC
# 2               	                	B-ISSUE 	I-VOL
# )               	✓               	B-PUNC  	B-PUNC
# ,               	✓               	B-PUNC  	B-PUNC
# 155             	✓               	B-PAGE  	B-PAGE
# -               	✓               	B-PUNC  	B-PUNC
# 183             	✓               	I-PAGE  	I-PAGE
# (               	✓               	B-PUNC  	B-PUNC
# 1995            	✓               	B-DATE  	B-DATE
# )               	✓               	B-PUNC  	B-PUNC
# .               	✓               	B-PUNC  	B-PUNC
#
# word  	unk   	pred tag   	true tag
# Horn  	      	B-AUTHOR   	B-AUTHOR
# ,     	✓     	B-PUNC     	B-PUNC
# B     	      	I-AUTHOR   	I-AUTHOR
# .     	✓     	B-PUNC     	B-PUNC
# (     	✓     	B-PUNC     	B-PUNC
# 1986  	✓     	B-DATE     	B-DATE
# )     	✓     	B-PUNC     	B-PUNC
# .     	✓     	B-PUNC     	B-PUNC
# Robot 	      	B-TITLE    	B-TITLE
# Vision	      	I-TITLE    	I-TITLE
# ,     	✓     	B-PUNC     	B-PUNC
# MIT   	      	B-PUBLISHER	B-PUBLISHER
# Press 	      	I-PUBLISHER	I-PUBLISHER
# .     	✓     	B-PUNC     	B-PUNC
#
# word           	unk            	pred tag	true tag
# J              	               	B-AUTHOR	B-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# McCarthy       	               	I-AUTHOR	I-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# Circumscription	               	B-TITLE 	B-TITLE
# a              	✓              	I-TITLE 	I-TITLE
# form           	               	I-TITLE 	I-TITLE
# of             	✓              	I-TITLE 	I-TITLE
# non            	               	I-TITLE 	I-TITLE
# -              	✓              	B-PUNC  	B-PUNC
# monotonic      	               	I-TITLE 	I-TITLE
# reasoning      	               	I-TITLE 	I-TITLE
# .              	✓              	B-PUNC  	B-PUNC
# Artificial     	               	B-CT    	B-CT
# Intelligence   	               	I-CT    	I-CT
# ,              	✓              	B-PUNC  	B-PUNC
# 13             	✓              	B-VOL   	B-VOL
# 27             	✓              	B-PAGE  	B-PAGE
# -              	✓              	B-PUNC  	B-PUNC
# 39171          	✓              	I-PAGE  	I-PAGE
# -              	✓              	B-PUNC  	B-PUNC
# 172            	✓              	I-PAGE  	I-PAGE
# 1980           	✓              	B-DATE  	B-DATE
# .              	✓              	B-PUNC  	B-PUNC
#
# word        	unk         	pred tag	true tag
# Whitley     	✓           	B-AUTHOR	B-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# D           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# ,           	✓           	B-PUNC  	B-PUNC
# &           	            	B-PUNC  	B-PUNC
# Gruau       	✓           	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# F           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# (           	✓           	B-PUNC  	B-PUNC
# 1993        	✓           	B-DATE  	B-DATE
# )           	✓           	B-PUNC  	B-PUNC
# .           	✓           	B-PUNC  	B-PUNC
# Adding      	            	B-TITLE 	B-TITLE
# learning    	            	I-TITLE 	I-TITLE
# to          	✓           	I-TITLE 	I-TITLE
# the         	            	I-TITLE 	I-TITLE
# cellular    	            	I-TITLE 	I-TITLE
# development 	            	I-TITLE 	I-TITLE
# of          	✓           	I-TITLE 	I-TITLE
# neural      	            	I-TITLE 	I-TITLE
# networks    	            	I-TITLE 	I-TITLE
# :           	✓           	B-PUNC  	B-PUNC
# Evolution   	            	I-TITLE 	I-TITLE
# and         	✓           	I-TITLE 	I-TITLE
# the         	            	I-TITLE 	I-TITLE
# Baldwin     	            	I-TITLE 	I-TITLE
# effect      	            	I-TITLE 	I-TITLE
# .           	✓           	B-PUNC  	B-PUNC
# Evolutionary	            	B-CT    	B-CT
# Computation 	            	I-CT    	I-CT
# ,           	✓           	B-PUNC  	B-PUNC
# 1           	            	B-ISSUE 	B-VOL
# ,           	✓           	B-PUNC  	B-PUNC
# 213         	✓           	B-PAGE  	B-PAGE
# -           	✓           	B-PUNC  	B-PUNC
# 233         	✓           	I-PAGE  	I-PAGE
#
# word           	unk            	pred tag	true tag
# Warren         	               	B-AUTHOR	B-AUTHOR
# R              	               	I-AUTHOR	I-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# Greiff         	✓              	B-TITLE 	I-AUTHOR
# .              	✓              	B-PUNC  	B-PUNC
# Computationally	               	B-TITLE 	B-TITLE
# tractable      	               	I-TITLE 	I-TITLE
# ,              	✓              	B-PUNC  	B-PUNC
# conceptually   	               	I-TITLE 	I-TITLE
# plausible      	               	I-TITLE 	I-TITLE
# classes        	               	I-TITLE 	I-TITLE
# of             	✓              	I-TITLE 	I-TITLE
# link           	               	I-TITLE 	I-TITLE
# matrices       	               	I-TITLE 	I-TITLE
# for            	               	I-TITLE 	I-TITLE
# the            	               	I-TITLE 	I-TITLE
# inquery        	✓              	I-TITLE 	I-TITLE
# inference      	               	I-TITLE 	I-TITLE
# network        	               	I-TITLE 	I-TITLE
# .              	✓              	B-PUNC  	B-PUNC
# September      	               	B-DATE  	B-DATE
# 1996           	✓              	I-DATE  	I-DATE
# .              	✓              	B-PUNC  	B-PUNC
#
# word     	unk      	pred tag	true tag
# Hinton   	✓        	B-AUTHOR	B-AUTHOR
# ,        	✓        	B-PUNC  	B-PUNC
# G        	         	I-AUTHOR	I-AUTHOR
# .        	✓        	B-PUNC  	B-PUNC
# E        	         	I-AUTHOR	I-AUTHOR
# .        	✓        	B-PUNC  	B-PUNC
# ,        	✓        	B-PUNC  	B-PUNC
# &        	         	B-PUNC  	B-PUNC
# Nowlan   	✓        	I-AUTHOR	I-AUTHOR
# ,        	✓        	B-PUNC  	B-PUNC
# S        	         	I-AUTHOR	I-AUTHOR
# .        	✓        	B-PUNC  	B-PUNC
# J        	         	I-AUTHOR	I-AUTHOR
# .        	✓        	B-PUNC  	B-PUNC
# (        	✓        	B-PUNC  	B-PUNC
# 1987     	✓        	B-DATE  	B-DATE
# )        	✓        	B-PUNC  	B-PUNC
# .        	✓        	B-PUNC  	B-PUNC
# How      	         	B-TITLE 	B-TITLE
# learning 	         	I-TITLE 	I-TITLE
# can      	         	I-TITLE 	I-TITLE
# guide    	         	I-TITLE 	I-TITLE
# evolution	         	I-TITLE 	I-TITLE
# .        	✓        	B-PUNC  	B-PUNC
# Complex  	         	B-CT    	B-CT
# Systems  	         	I-CT    	I-CT
# ,        	✓        	B-PUNC  	B-PUNC
# 1        	         	B-VOL   	B-VOL
# ,        	✓        	B-PUNC  	B-PUNC
# 495      	✓        	B-PAGE  	B-PAGE
# -        	✓        	B-PUNC  	B-PUNC
# 502      	✓        	I-PAGE  	I-PAGE
#
# word       	unk        	pred tag	true tag
# E          	           	B-AUTHOR	B-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Mohr       	           	I-AUTHOR	I-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# D          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# A          	✓          	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Kranz      	✓          	I-AUTHOR	I-AUTHOR
# ,          	✓          	B-PUNC  	B-PUNC
# and        	✓          	I-AUTHOR	I-AUTHOR
# R          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# H          	           	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Halstead   	✓          	I-AUTHOR	I-AUTHOR
# .          	✓          	B-PUNC  	B-PUNC
# Lazy       	           	I-AUTHOR	B-TITLE
# Task       	           	B-TITLE 	I-TITLE
# Creation   	           	I-TITLE 	I-TITLE
# :          	✓          	B-PUNC  	B-PUNC
# a          	✓          	I-TITLE 	I-TITLE
# Technique  	           	I-TITLE 	I-TITLE
# for        	           	I-TITLE 	I-TITLE
# Increasing 	           	I-TITLE 	I-TITLE
# the        	           	I-TITLE 	I-TITLE
# Granularity	           	I-TITLE 	I-TITLE
# of         	✓          	I-TITLE 	I-TITLE
# Parallel   	           	I-TITLE 	I-TITLE
# Programs   	           	I-TITLE 	I-TITLE
# .          	✓          	B-PUNC  	B-PUNC
# In         	           	O       	B-CT
# Proceedings	           	B-CT    	I-CT
# of         	✓          	I-CT    	I-CT
# the        	           	I-CT    	I-CT
# 1990       	✓          	I-CT    	I-CT
# ACM        	           	I-CT    	I-CT
# Conference 	           	I-CT    	I-CT
# on         	           	I-CT    	I-CT
# LISP       	           	I-CT    	I-CT
# and        	✓          	I-CT    	I-CT
# Functional 	           	I-CT    	I-CT
# Programming	           	I-CT    	I-CT
# ,          	✓          	B-PUNC  	B-PUNC
# 185        	✓          	I-CT    	B-PAGE
# -          	✓          	B-PUNC  	B-PUNC
# 197        	✓          	I-CT    	I-PAGE
# June       	           	I-CT    	B-DATE
# 1990       	✓          	I-CT    	I-DATE
# .          	✓          	B-PUNC  	B-PUNC
#
# word        	unk         	pred tag	true tag
# Gent        	            	B-AUTHOR	B-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# I           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# P           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# ,           	✓           	B-PUNC  	B-PUNC
# &           	            	B-PUNC  	B-PUNC
# Walsh       	            	I-AUTHOR	I-AUTHOR
# ,           	✓           	B-PUNC  	B-PUNC
# T           	            	I-AUTHOR	I-AUTHOR
# .           	✓           	B-PUNC  	B-PUNC
# (           	✓           	B-PUNC  	B-PUNC
# 1994a       	✓           	B-DATE  	B-DATE
# )           	✓           	B-PUNC  	B-PUNC
# .           	✓           	B-PUNC  	B-PUNC
# Easy        	            	B-TITLE 	B-TITLE
# problems    	            	I-TITLE 	I-TITLE
# are         	            	I-TITLE 	I-TITLE
# sometimes   	            	I-TITLE 	I-TITLE
# hard        	            	I-TITLE 	I-TITLE
# .           	✓           	B-PUNC  	B-PUNC
# Artificial  	            	B-CT    	B-CT
# Intelligence	            	I-CT    	I-CT
# ,           	✓           	B-PUNC  	B-PUNC
# 70          	✓           	B-VOL   	B-VOL
# ,           	✓           	B-PUNC  	B-PUNC
# 335         	✓           	B-PAGE  	B-PAGE
# -           	✓           	B-PUNC  	B-PUNC
# 345         	✓           	I-PAGE  	I-PAGE
#
# word         	unk          	pred tag	true tag
# Dyn          	             	B-AUTHOR	B-AUTHOR
# ,            	✓            	B-PUNC  	B-PUNC
# N            	             	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# and          	✓            	I-AUTHOR	I-AUTHOR
# A            	✓            	I-AUTHOR	I-AUTHOR
# .            	✓            	B-PUNC  	B-PUNC
# Ron          	             	I-AUTHOR	I-AUTHOR
# (            	✓            	B-PUNC  	B-PUNC
# 1993         	✓            	B-DATE  	B-DATE
# )            	✓            	B-PUNC  	B-PUNC
# "            	✓            	B-PUNC  	B-PUNC
# Radial       	             	B-TITLE 	B-TITLE
# basis        	             	I-TITLE 	I-TITLE
# function     	             	I-TITLE 	I-TITLE
# approximation	             	I-TITLE 	I-TITLE
# :            	✓            	B-PUNC  	B-PUNC
# from         	             	I-TITLE 	I-TITLE
# gridded      	             	I-TITLE 	I-TITLE
# centres      	✓            	I-TITLE 	I-TITLE
# to           	✓            	I-TITLE 	I-TITLE
# scattered    	             	I-TITLE 	I-TITLE
# centres      	✓            	I-TITLE 	I-TITLE
# "            	✓            	B-PUNC  	B-PUNC
# ,            	✓            	B-PUNC  	B-PUNC
#
# predicted_lables 50
# Precision-score: 95.4%
# Recal-score: 95.5%
# Current F1: 0.9542943244600703
# F1-score: 95.4%
# Classification-report
#               precision    recall  f1-score   support
#
#       AUTHOR       0.99      1.00      0.99       213
#           CT       0.62      0.68      0.65        47
#         DATE       0.92      0.94      0.93        50
#        ISSUE       0.00      0.00      0.00         0
#         PAGE       0.95      0.86      0.90        49
#    PUBLISHER       0.92      1.00      0.96        11
#         PUNC       1.00      1.00      1.00       522
#        TITLE       0.93      0.88      0.91        77
#          VOL       0.94      0.62      0.74        26
#
#    micro avg       0.95      0.95      0.95       995
#    macro avg       0.81      0.77      0.79       995
# weighted avg       0.96      0.95      0.96       995
#
# Average F1-score: 9.5%
# [0.99]
# Author f1: 0.99
# CT f1: 0.65
# date f1: 0.93
# PAGE f1: 0.9
# PUB f1: 0.96
# punc f1: 1.0
# title f1: 0.91
# vol f1: 0.74

# %%
'''
# Entity Level Performance

import utility

pred_author = []
true_author = []

for sentence in sentences[0:2]:
    for sentence in sentences:
        tokens = []
        true_tags = []
        
        for wt_tuple in sentence:
            token = wt_tuple[0]
            tag = wt_tuple[1]
            tokens.append(token)
            true_tags.append(tag)
        #tokens, true_tags = infersentence(sentence)
        predicted_tags = predictedtags(tokens,true_tags)
    print(sentence)
    tokens, true_tags, predicted_tags = infersentence(sentence)
    pauthors, ptitle, pcontainertitle, pissue, ppublisher, psource, pissn, pvolume, ppage, ppublication_year = glueTokens(tokens, predicted_tags)
    tauthors, ttitle, tcontainertitle, tissue, tpublisher, tsource, tissn, tvolume, tpage, tpublication_year = glueTokens(tokens, true_tags)
    
    # Author
    pred_author.append(pauthors)
    true_author.append(tauthors)

print("True Len: {}".format(len(true_author)))
print("Pred Len: {}".format(len(pred_author)))
print("True Author {}".format(true_author))
print("Pred Author {}".format(pred_author))
print("Author precision-score: {:.1%}".format(precision_score(true_author, pred_author)))
#cosine_value = utility.calculate_cosine_between_strings(fooditem.upper(),descriptionOnList.upper())
print(sentences[0])
'''
# Out:
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([19, 1, 400])
# pe shape: torch.Size([19, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([19, 1, 400])
# pe shape: torch.Size([19, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([58, 1, 400])
# pe shape: torch.Size([58, 1, 400])
# x shape:torch.Size([95, 1, 400])
# pe shape: torch.Size([95, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([69, 1, 400])
# pe shape: torch.Size([69, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([63, 1, 400])
# pe shape: torch.Size([63, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([19, 1, 400])
# pe shape: torch.Size([19, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([59, 1, 400])
# pe shape: torch.Size([59, 1, 400])
# x shape:torch.Size([58, 1, 400])
# pe shape: torch.Size([58, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([82, 1, 400])
# pe shape: torch.Size([82, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([81, 1, 400])
# pe shape: torch.Size([81, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([82, 1, 400])
# pe shape: torch.Size([82, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([7, 1, 400])
# pe shape: torch.Size([7, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([68, 1, 400])
# pe shape: torch.Size([68, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([58, 1, 400])
# pe shape: torch.Size([58, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([57, 1, 400])
# pe shape: torch.Size([57, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([62, 1, 400])
# pe shape: torch.Size([62, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([9, 1, 400])
# pe shape: torch.Size([9, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([79, 1, 400])
# pe shape: torch.Size([79, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([13, 1, 400])
# pe shape: torch.Size([13, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([70, 1, 400])
# pe shape: torch.Size([70, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([58, 1, 400])
# pe shape: torch.Size([58, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([62, 1, 400])
# pe shape: torch.Size([62, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([15, 1, 400])
# pe shape: torch.Size([15, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([68, 1, 400])
# pe shape: torch.Size([68, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([9, 1, 400])
# pe shape: torch.Size([9, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([62, 1, 400])
# pe shape: torch.Size([62, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([95, 1, 400])
# pe shape: torch.Size([95, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([74, 1, 400])
# pe shape: torch.Size([74, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([11, 1, 400])
# pe shape: torch.Size([11, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([58, 1, 400])
# pe shape: torch.Size([58, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([71, 1, 400])
# pe shape: torch.Size([71, 1, 400])
# x shape:torch.Size([13, 1, 400])
# pe shape: torch.Size([13, 1, 400])
# x shape:torch.Size([7, 1, 400])
# pe shape: torch.Size([7, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([12, 1, 400])
# pe shape: torch.Size([12, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([19, 1, 400])
# pe shape: torch.Size([19, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([74, 1, 400])
# pe shape: torch.Size([74, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([67, 1, 400])
# pe shape: torch.Size([67, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([75, 1, 400])
# pe shape: torch.Size([75, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([70, 1, 400])
# pe shape: torch.Size([70, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([74, 1, 400])
# pe shape: torch.Size([74, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([62, 1, 400])
# pe shape: torch.Size([62, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([15, 1, 400])
# pe shape: torch.Size([15, 1, 400])
# x shape:torch.Size([64, 1, 400])
# pe shape: torch.Size([64, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([63, 1, 400])
# pe shape: torch.Size([63, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([19, 1, 400])
# pe shape: torch.Size([19, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([12, 1, 400])
# pe shape: torch.Size([12, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([65, 1, 400])
# pe shape: torch.Size([65, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([110, 1, 400])
# pe shape: torch.Size([110, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([74, 1, 400])
# pe shape: torch.Size([74, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([11, 1, 400])
# pe shape: torch.Size([11, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([118, 1, 400])
# pe shape: torch.Size([118, 1, 400])
# x shape:torch.Size([12, 1, 400])
# pe shape: torch.Size([12, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([78, 1, 400])
# pe shape: torch.Size([78, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([6, 1, 400])
# pe shape: torch.Size([6, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([75, 1, 400])
# pe shape: torch.Size([75, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([12, 1, 400])
# pe shape: torch.Size([12, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([71, 1, 400])
# pe shape: torch.Size([71, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([69, 1, 400])
# pe shape: torch.Size([69, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([69, 1, 400])
# pe shape: torch.Size([69, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([13, 1, 400])
# pe shape: torch.Size([13, 1, 400])
# x shape:torch.Size([75, 1, 400])
# pe shape: torch.Size([75, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([79, 1, 400])
# pe shape: torch.Size([79, 1, 400])
# x shape:torch.Size([13, 1, 400])
# pe shape: torch.Size([13, 1, 400])
# x shape:torch.Size([11, 1, 400])
# pe shape: torch.Size([11, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([15, 1, 400])
# pe shape: torch.Size([15, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([324, 1, 400])
# pe shape: torch.Size([324, 1, 400])
# x shape:torch.Size([15, 1, 400])
# pe shape: torch.Size([15, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([6, 1, 400])
# pe shape: torch.Size([6, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([92, 1, 400])
# pe shape: torch.Size([92, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([67, 1, 400])
# pe shape: torch.Size([67, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([63, 1, 400])
# pe shape: torch.Size([63, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([63, 1, 400])
# pe shape: torch.Size([63, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([8, 1, 400])
# pe shape: torch.Size([8, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([11, 1, 400])
# pe shape: torch.Size([11, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([15, 1, 400])
# pe shape: torch.Size([15, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([8, 1, 400])
# pe shape: torch.Size([8, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([15, 1, 400])
# pe shape: torch.Size([15, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([12, 1, 400])
# pe shape: torch.Size([12, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([59, 1, 400])
# pe shape: torch.Size([59, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([149, 1, 400])
# pe shape: torch.Size([149, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([13, 1, 400])
# pe shape: torch.Size([13, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([13, 1, 400])
# pe shape: torch.Size([13, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([13, 1, 400])
# pe shape: torch.Size([13, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([63, 1, 400])
# pe shape: torch.Size([63, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([11, 1, 400])
# pe shape: torch.Size([11, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([72, 1, 400])
# pe shape: torch.Size([72, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([59, 1, 400])
# pe shape: torch.Size([59, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([62, 1, 400])
# pe shape: torch.Size([62, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([57, 1, 400])
# pe shape: torch.Size([57, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([76, 1, 400])
# pe shape: torch.Size([76, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([64, 1, 400])
# pe shape: torch.Size([64, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([76, 1, 400])
# pe shape: torch.Size([76, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([104, 1, 400])
# pe shape: torch.Size([104, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([57, 1, 400])
# pe shape: torch.Size([57, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([58, 1, 400])
# pe shape: torch.Size([58, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([74, 1, 400])
# pe shape: torch.Size([74, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([78, 1, 400])
# pe shape: torch.Size([78, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([57, 1, 400])
# pe shape: torch.Size([57, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([19, 1, 400])
# pe shape: torch.Size([19, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([80, 1, 400])
# pe shape: torch.Size([80, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([64, 1, 400])
# pe shape: torch.Size([64, 1, 400])
# x shape:torch.Size([30, 1, 400])
# pe shape: torch.Size([30, 1, 400])
# x shape:torch.Size([76, 1, 400])
# pe shape: torch.Size([76, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([101, 1, 400])
# pe shape: torch.Size([101, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([13, 1, 400])
# pe shape: torch.Size([13, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([74, 1, 400])
# pe shape: torch.Size([74, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([58, 1, 400])
# pe shape: torch.Size([58, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([12, 1, 400])
# pe shape: torch.Size([12, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([70, 1, 400])
# pe shape: torch.Size([70, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([75, 1, 400])
# pe shape: torch.Size([75, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([49, 1, 400])
# pe shape: torch.Size([49, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([11, 1, 400])
# pe shape: torch.Size([11, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([61, 1, 400])
# pe shape: torch.Size([61, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([23, 1, 400])
# pe shape: torch.Size([23, 1, 400])
# x shape:torch.Size([84, 1, 400])
# ...
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([15, 1, 400])
# pe shape: torch.Size([15, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([100, 1, 400])
# pe shape: torch.Size([100, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([54, 1, 400])
# pe shape: torch.Size([54, 1, 400])
# x shape:torch.Size([52, 1, 400])
# pe shape: torch.Size([52, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([67, 1, 400])
# pe shape: torch.Size([67, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([63, 1, 400])
# pe shape: torch.Size([63, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([60, 1, 400])
# pe shape: torch.Size([60, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([131, 1, 400])
# pe shape: torch.Size([131, 1, 400])
# x shape:torch.Size([97, 1, 400])
# pe shape: torch.Size([97, 1, 400])
# x shape:torch.Size([71, 1, 400])
# pe shape: torch.Size([71, 1, 400])
# x shape:torch.Size([59, 1, 400])
# pe shape: torch.Size([59, 1, 400])
# x shape:torch.Size([70, 1, 400])
# pe shape: torch.Size([70, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([57, 1, 400])
# pe shape: torch.Size([57, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([59, 1, 400])
# pe shape: torch.Size([59, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([32, 1, 400])
# pe shape: torch.Size([32, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([53, 1, 400])
# pe shape: torch.Size([53, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([63, 1, 400])
# pe shape: torch.Size([63, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([70, 1, 400])
# pe shape: torch.Size([70, 1, 400])
# x shape:torch.Size([44, 1, 400])
# pe shape: torch.Size([44, 1, 400])
# x shape:torch.Size([85, 1, 400])
# pe shape: torch.Size([85, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([50, 1, 400])
# pe shape: torch.Size([50, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([76, 1, 400])
# pe shape: torch.Size([76, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([58, 1, 400])
# pe shape: torch.Size([58, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([69, 1, 400])
# pe shape: torch.Size([69, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([71, 1, 400])
# pe shape: torch.Size([71, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([26, 1, 400])
# pe shape: torch.Size([26, 1, 400])
# x shape:torch.Size([61, 1, 400])
# pe shape: torch.Size([61, 1, 400])
# x shape:torch.Size([45, 1, 400])
# pe shape: torch.Size([45, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([41, 1, 400])
# pe shape: torch.Size([41, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([72, 1, 400])
# pe shape: torch.Size([72, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([65, 1, 400])
# pe shape: torch.Size([65, 1, 400])
# x shape:torch.Size([13, 1, 400])
# pe shape: torch.Size([13, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([46, 1, 400])
# pe shape: torch.Size([46, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([51, 1, 400])
# pe shape: torch.Size([51, 1, 400])
# x shape:torch.Size([63, 1, 400])
# pe shape: torch.Size([63, 1, 400])
# x shape:torch.Size([28, 1, 400])
# pe shape: torch.Size([28, 1, 400])
# x shape:torch.Size([33, 1, 400])
# pe shape: torch.Size([33, 1, 400])
# x shape:torch.Size([72, 1, 400])
# pe shape: torch.Size([72, 1, 400])
# x shape:torch.Size([12, 1, 400])
# pe shape: torch.Size([12, 1, 400])
# x shape:torch.Size([55, 1, 400])
# pe shape: torch.Size([55, 1, 400])
# x shape:torch.Size([56, 1, 400])
# pe shape: torch.Size([56, 1, 400])
# x shape:torch.Size([18, 1, 400])
# pe shape: torch.Size([18, 1, 400])
# x shape:torch.Size([19, 1, 400])
# pe shape: torch.Size([19, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([42, 1, 400])
# pe shape: torch.Size([42, 1, 400])
# x shape:torch.Size([40, 1, 400])
# pe shape: torch.Size([40, 1, 400])
# x shape:torch.Size([31, 1, 400])
# pe shape: torch.Size([31, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([16, 1, 400])
# pe shape: torch.Size([16, 1, 400])
# x shape:torch.Size([20, 1, 400])
# pe shape: torch.Size([20, 1, 400])
# x shape:torch.Size([48, 1, 400])
# pe shape: torch.Size([48, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([39, 1, 400])
# pe shape: torch.Size([39, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([37, 1, 400])
# pe shape: torch.Size([37, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([21, 1, 400])
# pe shape: torch.Size([21, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([17, 1, 400])
# pe shape: torch.Size([17, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# x shape:torch.Size([22, 1, 400])
# pe shape: torch.Size([22, 1, 400])
# x shape:torch.Size([27, 1, 400])
# pe shape: torch.Size([27, 1, 400])
# x shape:torch.Size([24, 1, 400])
# pe shape: torch.Size([24, 1, 400])
# x shape:torch.Size([14, 1, 400])
# pe shape: torch.Size([14, 1, 400])
# x shape:torch.Size([34, 1, 400])
# pe shape: torch.Size([34, 1, 400])
# x shape:torch.Size([64, 1, 400])
# pe shape: torch.Size([64, 1, 400])
# x shape:torch.Size([58, 1, 400])
# pe shape: torch.Size([58, 1, 400])
# x shape:torch.Size([36, 1, 400])
# pe shape: torch.Size([36, 1, 400])
# x shape:torch.Size([25, 1, 400])
# pe shape: torch.Size([25, 1, 400])
# x shape:torch.Size([35, 1, 400])
# pe shape: torch.Size([35, 1, 400])
# x shape:torch.Size([62, 1, 400])
# pe shape: torch.Size([62, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([38, 1, 400])
# pe shape: torch.Size([38, 1, 400])
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# x shape:torch.Size([47, 1, 400])
# pe shape: torch.Size([47, 1, 400])
# x shape:torch.Size([29, 1, 400])
# pe shape: torch.Size([29, 1, 400])
# [('Slastenin', 'B-AUTHOR'), ('VA', 'I-AUTHOR'), ('Training', 'B-TITLE'), ('creative', 'I-TITLE'), ('teachers', 'I-TITLE'), ('in', 'I-TITLE'), ('the', 'I-TITLE'), ('Union', 'I-TITLE'), ('of', 'I-TITLE'), ('Soviet', 'I-TITLE'), ('Socialist', 'I-TITLE'), ('Republics', 'I-TITLE'), ('.', 'B-PUNC'), ('Prospects', 'B-CT'), ('[', 'B-PUNC'), ('Internet', 'O'), (']', 'B-PUNC'), ('Springer', 'B-PUBLISHER'), ('Nature', 'I-PUBLISHER'), (',', 'B-PUNC'), ('1975', 'B-DATE'), (';', 'B-PUNC'), ('5', 'B-VOL'), (':', 'B-PUNC'), ('255263', 'B-PAGE'), ('.', 'B-PUNC'), ('Available', 'O'), ('from', 'O'), (':', 'B-PUNC')]
# x shape:torch.Size([145, 1, 400])
# pe shape: torch.Size([145, 1, 400])
# Glued
# authors: Slastenin VA Training creative teachers in the Union of Soviet 5
# title: Socialist Republics
# containertitle: Internet 1975 Available from Slastenin VA Training creative teachers in the Union of Soviet Socialist Republics Prospects Internet Springer Nature 1975 5 Available from Slastenin VA Training creative teachers in the Union of Soviet Socialist Republics Prospects Springer Nature 1975 5 Slastenin VA Training creative Prospects Springer Nature 1975 5 Slastenin VA Training creative Springer Nature 1975 5 Available from
# issue:
# publisher: Prospects Springer Nature Soviet Socialist Republics Prospects
# source:
# issn:
# volume:
# page: 255263 255263 255263 255263 255263
# publication_year:
# Glued
# authors: Slastenin VA Slastenin VA Slastenin VA Slastenin VA Slastenin VA
# title: Training creative teachers in the Union of Soviet Socialist Republics Training creative teachers in the Union of Soviet Socialist Republics Training creative teachers in the Union of Soviet Socialist Republics Training creative teachers in the Union of Soviet Socialist Republics Training creative teachers in the Union of Soviet Socialist Republics
# containertitle: Prospects Prospects Prospects Prospects Prospects
# issue:
# publisher: Springer Nature Springer Nature Springer Nature Springer Nature Springer Nature
# source:
# issn:
# volume: 5 5 5 5 5
# page: 255263 255263 255263 255263 255263
# publication_year: 1975 1975 1975 1975 1975
# True Len: 2
# Pred Len: 2
# True Author ['Slastenin VA Slastenin VA Slastenin VA Slastenin VA', 'Slastenin VA Slastenin VA Slastenin VA Slastenin VA Slastenin VA']
# Pred Author ['Slastenin VA Training creative teachers in the Union of 5', 'Slastenin VA Training creative teachers in the Union of Soviet 5']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d2c10cfba251> in <module>
#      31 print("True Author {}".format(true_author))
#      32 print("Pred Author {}".format(pred_author))
# ---> 33 print("Author precision-score: {:.1%}".format(precision_score(true_author, pred_author)))
#      34 #cosine_value = utility.calculate_cosine_between_strings(fooditem.upper(),descriptionOnList.upper())
#      35 print(sentences[0])
#
# ~/envs/citationparser/lib/python3.7/site-packages/seqeval/metrics/sequence_labeling.py in precision_score(y_true, y_pred, average, suffix, mode, sample_weight, zero_division, scheme)
#     485                                                      sample_weight=sample_weight,
#     486                                                      zero_division=zero_division,
# --> 487                                                      suffix=suffix)
#     488     return p
#     489
#
# ~/envs/citationparser/lib/python3.7/site-packages/seqeval/metrics/sequence_labeling.py in precision_recall_fscore_support(y_true, y_pred, average, warn_for, beta, sample_weight, zero_division, suffix)
#     137         scheme=None,
#     138         suffix=suffix,
# --> 139         extract_tp_actual_correct=extract_tp_actual_correct
#     140     )
#     141
#
# ~/envs/citationparser/lib/python3.7/site-packages/seqeval/metrics/v1.py in _precision_recall_fscore_support(y_true, y_pred, average, warn_for, beta, sample_weight, zero_division, scheme, suffix, extract_tp_actual_correct)
#     120         raise ValueError('average has to be one of {}'.format(average_options))
#     121
# --> 122     check_consistent_length(y_true, y_pred)
#     123
#     124     pred_sum, tp_sum, true_sum = extract_tp_actual_correct(y_true, y_pred, suffix, scheme)
#
# ~/envs/citationparser/lib/python3.7/site-packages/seqeval/metrics/v1.py in check_consistent_length(y_true, y_pred)
#      95     is_list = set(map(type, y_true)) | set(map(type, y_pred))
#      96     if not is_list == {list}:
# ---> 97         raise TypeError('Found input variables without list of list.')
#      98
#      99     if len(y_true) != len(y_pred) or len_true != len_pred:
#
# TypeError: Found input variables without list of list.

# %%
'''
    Unknown citaiotion string testing zone
'''
'''
import re
def reference_string_tokenizerA(citationString):

    charPattern = r"[\w\d]"
    noCharPattern = r"[\W]"
    endPtr = 0
    word = ""
    tokens = []
    while endPtr < len(citationString):
      if re.search(charPattern, citationString[endPtr]):
        word += citationString[endPtr]
      elif re.search(noCharPattern, citationString[endPtr]):
        if word is not "":
          tokens.append(word)   
        tokens.append(citationString[endPtr])
        word = ""

      endPtr = endPtr + 1
    
    tokensWithoutSpace = []
    for item in tokens:
        if item is not " ":
            tokensWithoutSpace.append(item)
    print(tokensWithoutSpace)
    return tokensWithoutSpace

sentence = "Lomolino, M. et al. (2013) ‘Of mice and mammoths: generality and antiquity of the island rule’, Journal of Biogeography, 40(8), pp. 1427-1439. Available at:"
print("Original reference string: {}".format(sentence))
#tags = ["O", "O", "O", "O", "O", "O", "O", "B-PERSON", "I-PERSON", "L-PERSON", "O", "O", "B-ORGANIZATION", "I-ORGANIZATION", "I-ORGANIZATION", "L-ORGANIZATION", "O", "O", "O", "O", "O", "O", "O", "O", "U-PERSON", "O", "O", "O", "O", "B-TIME", "I-TIME", "I-TIME", "I-TIME", "I-TIME", "I-TIME", "I_TIME", "L-TIME", "O"]
tokens = reference_string_tokenizerA(sentence)
predicted_tags = infer(model, tokens=tokens, device=use_device, infer_unknown_sentence=True)

print("Parse metadata from unknown reference string")
glueTokens(tokens=tokens, predicted_tags=predicted_tags)
'''
'''
          [500,  1K,  10K,  22K,  100K, 220K, 342K, 1M]
Avg:      [84.7,87.4,87.7, 92.2,  93.5, 94.2, 93.6, 93.4]    
Author:   [94.2,95.3,96.0, 97.9,  98.0, 98.8, 98.8, 98.5]
CT:       [40.7,48.7,53.0, 56.1,  60.2, 62.1, 61.3, 60.1]
Date:     [48.4,61.0,48.5, 83.1,  91.2, 87.7, 84.5, 86.0]
Page:     [53.5,62.4,60.6, 71.1,  81.6, 84.4, 77.5, 76.2]
Publisher:[48.2,62.2,59.0, 81.7,  87.3, 91.4, 92.9, 89.59]
Punc:     [99.6,99.0,100,  100 ,  100 ,  100, 100 , 100 ]
Title:    [65.9,72.4,73.5, 87.5,  87.8, 90.7, 90.2, 91.2]
Vol:      [39.4,46.6,39.5, 51.5,  54.9, 65.2, 62.5, 58.4]



After 8th epoch on 1M:

Average F1-score: 93.4%
Author f1: 0.9850000000000001
CT f1: 0.6010000000000001
date f1: 0.8600000000000001
PAGE f1: 0.7629999999999999
PUB f1: 0.8959999999999999
punc f1: 1.0
title f1: 0.9120000000000001
vol f1: 0.5840000000000001
'''
# Out:
# Original reference string: Lomolino, M. et al. (2013) ‘Of mice and mammoths: generality and antiquity of the island rule’, Journal of Biogeography, 40(8), pp. 1427-1439. Available at:
# ['Lomolino', ',', 'M', '.', 'et', 'al', '.', '(', '2013', ')', '‘', 'Of', 'mice', 'and', 'mammoths', ':', 'generality', 'and', 'antiquity', 'of', 'the', 'island', 'rule', '’', ',', 'Journal', 'of', 'Biogeography', ',', '40', '(', '8', ')', ',', 'pp', '.', '1427', '-', '1439', '.', 'Available', 'at', ':']
# x shape:torch.Size([43, 1, 400])
# pe shape: torch.Size([43, 1, 400])
# word        	unk         	pred tag
# Lomolino    	✓           	B-AUTHOR
# ,           	✓           	B-PUNC
# M           	            	I-AUTHOR
# .           	✓           	B-PUNC
# et          	            	I-AUTHOR
# al          	            	I-AUTHOR
# .           	✓           	B-PUNC
# (           	✓           	B-PUNC
# 2013        	✓           	B-CT
# )           	✓           	B-PUNC
# ‘           	✓           	B-PUNC
# Of          	✓           	I-CT
# mice        	            	I-CT
# and         	✓           	I-CT
# mammoths    	            	I-CT
# :           	✓           	B-PUNC
# generality  	            	I-CT
# and         	✓           	I-CT
# antiquity   	            	I-CT
# of          	✓           	I-CT
# the         	            	I-CT
# island      	            	I-CT
# rule        	            	I-CT
# ’           	✓           	B-PUNC
# ,           	✓           	B-PUNC
# Journal     	            	B-CT
# of          	✓           	I-CT
# Biogeography	            	I-CT
# ,           	✓           	B-PUNC
# 40          	✓           	B-VOL
# (           	✓           	B-PUNC
# 8           	            	B-ISSUE
# )           	✓           	B-PUNC
# ,           	✓           	B-PUNC
# pp          	            	O
# .           	✓           	B-PUNC
# 1427        	✓           	B-PAGE
# -           	✓           	B-PUNC
# 1439        	✓           	B-DATE
# .           	✓           	B-PUNC
# Available   	            	O
# at          	            	O
# :           	✓           	B-PUNC
# Parse metadata from unknown reference string
# Glued
# authors:
# title:
# containertitle:
# issue: 8
# publisher:
# source:
# issn:
# volume: 40
# page: 1427
# publication_month:
# publication_year: 1439
# ('', '', '', '8', '', '', '', '40', '1427', '', '1439')

# %%
from seqeval.metrics import accuracy_score
from seqeval.metrics import classification_report
from seqeval.metrics import f1_score
y_true = [['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O'], ['B-PER', 'I-PER', 'O']]
y_pred = [['O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O'], ['B-PER', 'I-PER', 'O']]
print(f1_score(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# 0.5
#               precision    recall  f1-score   support
#
#         MISC       0.00      0.00      0.00         1
#          PER       1.00      1.00      1.00         1
#
#    micro avg       0.50      0.50      0.50         2
#    macro avg       0.50      0.50      0.50         2
# weighted avg       0.50      0.50      0.50         2
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
from seqeval.metrics import accuracy_score
from seqeval.metrics import classification_report
from seqeval.metrics import f1_score
y_true = [['B-CT', 'I-CT', 'I-CT','I-CT', 'O'], ['B-TITLE', 'I-TITLE', 'O']]
y_pred = [['B-CT', 'I-CT', 'I-CT','I-TITLE','O'], ['B-TITLE', 'I-TITLE', 'O']]
print(f1_score(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# 0.4
#               precision    recall  f1-score   support
#
#           CT       0.00      0.00      0.00         1
#        TITLE       0.50      1.00      0.67         1
#
#    micro avg       0.33      0.50      0.40         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
